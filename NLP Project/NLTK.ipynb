# %%
import nltk
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = '''Inflation rose again in April, continuing a climb that has pushed consumers to the brink and is threatening the economic expansion, the Bureau of Labor Statistics reported Wednesday.

The consumer price index, a broad-based measure of prices for goods and services, increased 8.3% from a year ago, higher than the Dow Jones estimate for an 8.1% gain. That represented a slight ease from March’s peak but was still close to the highest level since the summer of 1982.

Removing volatile food and energy prices, so-called core CPI still rose 6.2%, against expectations for a 6% gain, clouding hopes that inflation had peaked in March.

The month-over-month gains also were higher than expectations — 0.3% on headline CPI versus the 0.2% estimate and a 0.6% increase for core, against the outlook for a 0.4% gain.

The price gains also meant that workers continued to lose ground. Real wages adjusted for inflation decreased 0.1% on the month despite a nominal increase of 0.3% in average hourly earnings. Over the past year, real earnings have dropped 2.6% even though average hourly earnings are up 5.5%.

Inflation has been the single biggest threat to a recovery that began early in the Covid pandemic and saw the economy in 2021 stage its biggest single-year growth level since 1984. Rising prices at the pump and in grocery stores have been one problem, but inflation has spread beyond those two areas into housing, auto sales and a host of other areas.

Federal Reserve officials have responded to the problem with two interest rate hikes so far this year and pledges of more until inflation comes down to the central bank’s 2% goal. However, Wednesday’s data shows that the Fed has a big job ahead.

Credits: cnbc.com '''


text =''' 1k Cr Spent On Drainage &amp; Flood Control In 7 Yrs, Yet Flooding Threat Looms Large | Gurgaon News - Times of India https://t.co/m9SyxzAWEj'''

# %%
for token in doc:
    print ( token.text , "\\", token.pos_, spacy.explain(token.pos))
# Out:
# Inflation \ NOUN None
# rose \ VERB None
# again \ ADV None
# in \ ADP None
# April \ PROPN None
# , \ PUNCT None
# continuing \ VERB None
# a \ DET None
# climb \ NOUN None
# that \ PRON None
# has \ AUX None
# pushed \ VERB None
# consumers \ NOUN None
# to \ ADP None
# the \ DET None
# brink \ NOUN None
# and \ CCONJ None
# is \ AUX None
# threatening \ VERB None
# the \ DET None
# economic \ ADJ None
# expansion \ NOUN None
# , \ PUNCT None
# the \ DET None
# Bureau \ PROPN None
# of \ ADP None
# Labor \ PROPN None
# Statistics \ PROPN None
# reported \ VERB None
# Wednesday \ PROPN None
# . \ PUNCT None
#
#
#  \ SPACE None
# The \ DET None
# consumer \ NOUN None
# price \ NOUN None
# index \ NOUN None
# , \ PUNCT None
# a \ DET None
# broad \ ADV None
# - \ PUNCT None
# based \ VERB None
# measure \ NOUN None
# of \ ADP None
# prices \ NOUN None
# for \ ADP None
# goods \ NOUN None
# and \ CCONJ None
# services \ NOUN None
# , \ PUNCT None
# increased \ VERB None
# 8.3 \ NUM None
# % \ NOUN None
# from \ ADP None
# a \ DET None
# year \ NOUN None
# ago \ ADV None
# , \ PUNCT None
# higher \ ADJ None
# than \ ADP None
# the \ DET None
# Dow \ PROPN None
# Jones \ PROPN None
# estimate \ NOUN None
# for \ ADP None
# an \ DET None
# 8.1 \ NUM None
# % \ NOUN None
# gain \ NOUN None
# . \ PUNCT None
# That \ PRON None
# represented \ VERB None
# a \ DET None
# slight \ ADJ None
# ease \ NOUN None
# from \ ADP None
# March \ PROPN None
# ’s \ PART None
# peak \ NOUN None
# but \ CCONJ None
# was \ AUX None
# still \ ADV None
# close \ ADJ None
# to \ ADP None
# the \ DET None
# highest \ ADJ None
# level \ NOUN None
# since \ SCONJ None
# the \ DET None
# summer \ NOUN None
# of \ ADP None
# 1982 \ NUM None
# . \ PUNCT None
#
#
#  \ SPACE None
# Removing \ VERB None
# volatile \ ADJ None
# food \ NOUN None
# and \ CCONJ None
# energy \ NOUN None
# prices \ NOUN None
# , \ PUNCT None
# so \ ADV None
# - \ PUNCT None
# called \ VERB None
# core \ NOUN None
# CPI \ PROPN None
# still \ ADV None
# rose \ VERB None
# 6.2 \ NUM None
# % \ NOUN None
# , \ PUNCT None
# against \ ADP None
# expectations \ NOUN None
# for \ ADP None
# a \ DET None
# 6 \ NUM None
# % \ NOUN None
# gain \ NOUN None
# , \ PUNCT None
# clouding \ VERB None
# hopes \ NOUN None
# that \ SCONJ None
# inflation \ NOUN None
# had \ AUX None
# peaked \ VERB None
# in \ ADP None
# March \ PROPN None
# . \ PUNCT None
#
#
#  \ SPACE None
# The \ DET None
# month \ NOUN None
# - \ PUNCT None
# over \ ADP None
# - \ PUNCT None
# month \ NOUN None
# gains \ NOUN None
# also \ ADV None
# were \ AUX None
# higher \ ADJ None
# than \ ADP None
# expectations \ NOUN None
# — \ PUNCT None
# 0.3 \ NUM None
# % \ NOUN None
# on \ ADP None
# headline \ NOUN None
# CPI \ PROPN None
# versus \ ADP None
# the \ DET None
# 0.2 \ NUM None
# % \ NOUN None
# estimate \ NOUN None
# and \ CCONJ None
# a \ DET None
# 0.6 \ NUM None
# % \ NOUN None
# increase \ NOUN None
# for \ ADP None
# core \ NOUN None
# , \ PUNCT None
# against \ ADP None
# the \ DET None
# outlook \ NOUN None
# for \ ADP None
# a \ DET None
# 0.4 \ NUM None
# % \ NOUN None
# gain \ NOUN None
# . \ PUNCT None
#
#
#  \ SPACE None
# The \ DET None
# price \ NOUN None
# gains \ NOUN None
# also \ ADV None
# meant \ VERB None
# that \ SCONJ None
# workers \ NOUN None
# continued \ VERB None
# to \ PART None
# lose \ VERB None
# ground \ NOUN None
# . \ PUNCT None
# Real \ ADJ None
# wages \ NOUN None
# adjusted \ VERB None
# for \ ADP None
# inflation \ NOUN None
# decreased \ VERB None
# 0.1 \ NUM None
# % \ NOUN None
# on \ ADP None
# the \ DET None
# month \ NOUN None
# despite \ SCONJ None
# a \ DET None
# nominal \ ADJ None
# increase \ NOUN None
# of \ ADP None
# 0.3 \ NUM None
# % \ NOUN None
# in \ ADP None
# average \ ADJ None
# hourly \ ADJ None
# earnings \ NOUN None
# . \ PUNCT None
# Over \ ADP None
# the \ DET None
# past \ ADJ None
# year \ NOUN None
# , \ PUNCT None
# real \ ADJ None
# earnings \ NOUN None
# have \ AUX None
# dropped \ VERB None
# 2.6 \ NUM None
# % \ NOUN None
# even \ ADV None
# though \ SCONJ None
# average \ ADJ None
# hourly \ ADJ None
# earnings \ NOUN None
# are \ AUX None
# up \ ADV None
# 5.5 \ NUM None
# % \ NOUN None
# . \ PUNCT None
#
#
#  \ SPACE None
# Inflation \ NOUN None
# has \ AUX None
# been \ AUX None
# the \ DET None
# single \ ADJ None
# biggest \ ADJ None
# threat \ NOUN None
# to \ ADP None
# a \ DET None
# recovery \ NOUN None
# that \ PRON None
# began \ VERB None
# early \ ADV None
# in \ ADP None
# the \ DET None
# Covid \ PROPN None
# pandemic \ NOUN None
# and \ CCONJ None
# saw \ VERB None
# the \ DET None
# economy \ NOUN None
# in \ ADP None
# 2021 \ NUM None
# stage \ NOUN None
# its \ PRON None
# biggest \ ADJ None
# single \ ADJ None
# - \ PUNCT None
# year \ NOUN None
# growth \ NOUN None
# level \ NOUN None
# since \ SCONJ None
# 1984 \ NUM None
# . \ PUNCT None
# Rising \ VERB None
# prices \ NOUN None
# at \ ADP None
# the \ DET None
# pump \ NOUN None
# and \ CCONJ None
# in \ ADP None
# grocery \ NOUN None
# stores \ NOUN None
# have \ AUX None
# been \ AUX None
# one \ NUM None
# problem \ NOUN None
# , \ PUNCT None
# but \ CCONJ None
# inflation \ NOUN None
# has \ AUX None
# spread \ VERB None
# beyond \ ADP None
# those \ DET None
# two \ NUM None
# areas \ NOUN None
# into \ ADP None
# housing \ NOUN None
# , \ PUNCT None
# auto \ NOUN None
# sales \ NOUN None
# and \ CCONJ None
# a \ DET None
# host \ NOUN None
# of \ ADP None
# other \ ADJ None
# areas \ NOUN None
# . \ PUNCT None
#
#
#  \ SPACE None
# Federal \ PROPN None
# Reserve \ PROPN None
# officials \ NOUN None
# have \ AUX None
# responded \ VERB None
# to \ ADP None
# the \ DET None
# problem \ NOUN None
# with \ ADP None
# two \ NUM None
# interest \ NOUN None
# rate \ NOUN None
# hikes \ NOUN None
# so \ ADV None
# far \ ADV None
# this \ DET None
# year \ NOUN None
# and \ CCONJ None
# pledges \ NOUN None
# of \ ADP None
# more \ ADJ None
# until \ SCONJ None
# inflation \ NOUN None
# comes \ VERB None
# down \ ADP None
# to \ ADP None
# the \ DET None
# central \ ADJ None
# bank \ NOUN None
# ’s \ PART None
# 2 \ NUM None
# % \ NOUN None
# goal \ NOUN None
# . \ PUNCT None
# However \ ADV None
# , \ PUNCT None
# Wednesday \ PROPN None
# ’s \ PART None
# data \ NOUN None
# shows \ VERB None
# that \ SCONJ None
# the \ DET None
# Fed \ PROPN None
# has \ VERB None
# a \ DET None
# big \ ADJ None
# job \ NOUN None
# ahead \ ADV None
# . \ PUNCT None
#
#
#  \ SPACE None
# Credits \ NOUN None
# : \ PUNCT None
# cnbc.com \ X None
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '92' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '100' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '86' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '85' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '96' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '97' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '90' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '95' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '87' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '89' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '84' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '103' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '93' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '94' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '98' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))
# /home/krishna/anaconda3/lib/python3.9/site-packages/spacy/glossary.py:19: UserWarning: [W118] Term '101' not found in glossary. It may however be explained in documentation for the corpora used to train the language. Please check `nlp.meta["sources"]` for any relevant links.
#   warnings.warn(Warnings.W118.format(term=term))

# %%
doc = nlp(text)

noun =[]
num =[]
for token in doc:
    if token.pos_ == 'NOUN' :
        noun.append(token)
    elif token.pos_ == 'NUM':
        num.append(token.text)

num
# Out:
# ['7']

# %%
count = doc.count_by(spacy.attrs.POS)
count
# Out:
# {103: 1, 96: 13, 100: 3, 85: 3, 89: 2, 97: 3, 93: 1, 84: 1, 92: 1}

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
from spacy import displacy

displacy.render(doc, style ="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1k
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cr Spent On Drainage &amp;
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# amp;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Flood Control
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  In 7 Yrs, Yet Flooding Threat Looms Large |
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gurgaon News - Times of India
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  https://t.co/m9SyxzAWEj</div></span>
