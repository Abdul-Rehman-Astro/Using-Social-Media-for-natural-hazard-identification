# %%
import nltk
import spacy
import pandas as pd
import numpy as np

nlp = spacy.load("en_core_web_sm")

# %%
df= pd.read_excel("/media/krishna/88356b6e-eda9-4612-9c56-c44911a1b8ae/NLP Project/Data Scrape/twitter.xlsx")
df.head()
df.shape
# Out:
# (2866, 7)

# %%
df["Location_extracted"] =''
df
# text = """Kiran want to know the famous foods in each state of India. So, he opened Google and search for this question. Google showed that
# in Delhi it is Chaat, in Gujarat it is Dal Dhokli, in Tamilnadu it is Pongal, in Andhrapradesh it is Biryani, in Assam it is Papaya Khar,
# in Bihar it is Litti Chowkha and so on for all other states"""

# doc = nlp(text)
# doc.ents

df["content"].shape

location =[]
for i in range(2866):# 2866
    text = df["content"][i]
    doc = nlp(text)

    # location =[]

    l=[]
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            l.append(ent)
    
    if(len(l)==0):
        l.append("N/A")

    location.append(l)
    del(l)
    

location= np.array(location)
location
df["Location_extracted"]= location

df["Location_extracted"]
# Out:
# /tmp/ipykernel_10245/1883569930.py:31: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   location= np.array(location)
# 0                       [N/A]
# 1                   [(Assam)]
# 2                   [(India)]
# 3                       [N/A]
# 4                       [N/A]
#                 ...
# 2861             [(Mindanao)]
# 2862       [(India), (India)]
# 2863                    [N/A]
# 2864                    [N/A]
# 2865    [(Guwahati), (India)]
# Name: Location_extracted, Length: 2866, dtype: object

# %%
df = df(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8417/2673482176.py in <module>
# ----> 1 df(inplace = True)
#
# TypeError: 'DataFrame' object is not callable

# %%
df.tail(20)
# Out:
#            date                   id  \
# 2846 2022-12-28  1607947581828800000
# 2847 2022-12-28  1607938641656950016
# 2848 2022-12-27  1607777980679610112
# 2849 2022-12-27  1607732934890639872
# 2850 2022-12-27  1607730535211699968
# 2851 2022-12-27  1607659828960450048
# 2852 2022-12-27  1607638314701710080
# 2853 2022-12-27  1607580151860110080
# 2854 2022-12-27  1607558117654400000
# 2855 2022-12-26  1607423005533299968
# 2856 2022-12-26  1607414671438670080
# 2857 2022-12-26  1607412592607389952
# 2858 2022-12-26  1607355502450840064
# 2859 2022-12-26  1607350022060019968
# 2860 2022-12-26  1607322561272069888
# 2861 2022-12-26  1607271617553649920
# 2862 2022-12-26  1607261799170160128
# 2863 2022-12-26  1607244545246530048
# 2864 2022-12-26  1607244305122599936
# 2865 2022-12-26  1607225869885479936
#
#                                                 content         username  \
# 2846  #askabhijit  what was happening in india durin...  abhaysi09843871
# ...

# %%
df.to_excel("loaction_extracted.xlsx")
