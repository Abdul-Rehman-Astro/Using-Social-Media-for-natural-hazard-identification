# %%
#reference : https://www.youtube.com/watch?v=PUMMCLrVn8A&ab_channel=RobMulla

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-gkrvt9yq
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-gkrvt9yq
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 614d4c2029a62d348ca56598f87c425966aaec66
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests[socks] in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (2.28.1)
# Requirement already satisfied: lxml in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (4.11.1)
# Requirement already satisfied: filelock in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /home/krishna/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->snscrape==0.7.0.20230622) (2.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (2022.9.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (1.7.1)
# Building wheels for collected packages: snscrape
#   Building wheel for snscrape (pyproject.toml) ... done
#   Created wheel for snscrape: filename=snscrape-0.7.0.20230622-py3-none-any.whl size=74814 sha256=f2e31dd35693f11467fcb30a5d14a4797cba9a4e5ffffb652ed5326739485948
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gvx7sxwj/wheels/1a/ba/e2/39fa3a11802c4a622f2efc8be3f5ff854481051d0b4c95c1fd
# Successfully built snscrape
# Installing collected packages: snscrape
# Successfully installed snscrape-0.7.0.20230622
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
# scraper = sntwitter.TwitterSearchScraper('seagames since:2023-04-01 until:2023-05-19')
scraper = sntwitter.TwitterSearchScraper('flood in india')

# flood  "Flood " (flood OR cloudburst OR Monsoon ) (#flood) min_replies:5 min_faves:100 min_retweets:10 lang:en until:2022-09-30 since:2022-06-01
# scraper = sntwitter.TwitterSearchScraper('flood  "Flood " (flood OR cloudburst OR Monsoon ) (#flood) min_replies:5 min_faves:100 min_retweets:10 lang:en until:2022-09-30 since:2022-06-01')

#flood  "flood" (flood OR Monsoon) -Pakisthan -Bangladesh -California(#Flood) min_replies:2 min_faves:50 min_retweets:5 lang:en since:2022-06-01

# scraper = sntwitter.TwitterSearchScraper('flood  "flood" (flood OR Monsoon) -Pakisthan -Bangladesh -California(#Flood) min_replies:2 min_faves:50 min_retweets:5 lang:en since:2022-06-01')

# %%
type(scraper)
# Out:
# snscrape.modules.twitter.TwitterSearchScraper

# %%
tweet_data=[]
for i,tweet in enumerate(scraper.get_items()): 
    tweet_list=[tweet.date,
            tweet.id, 
            tweet.content,
            tweet.user.username,
            tweet.likeCount,
            tweet.retweetCount,
            tweet.replyCount]
    tweet_data.append(tweet_list)
    if i==10000 :
        break
# Out:
# /tmp/ipykernel_99313/3117837193.py:5: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,
# Could not translate t.co card URL on tweet 1671438195093823492
# Could not translate t.co card URL on tweet 1669960865410428928
# Unavailable user in card on tweet 1669655967192219648
# User 1667612219654262789 not found in user refs in card on tweet 1669655967192219648
# Unavailable user in card on tweet 1660414147329413120
# User 1411470135496298499 not found in user refs in card on tweet 1660414147329413120
# Could not translate t.co card URL on tweet 1659120942273146880
# Could not translate t.co card URL on tweet 1656721761855995912
# Could not translate t.co card URL on tweet 1654536089057603592
# Could not translate t.co card URL on tweet 1637518205940903939
# Could not translate t.co card URL on tweet 1634227975649472514
# Unavailable user in card on tweet 1618085881633714179
# Unavailable user in card on tweet 1618085881633714179
# User 1150370223209324545 not found in user refs in card on tweet 1618085881633714179
# User 1150370223209324545 not found in user refs in card on tweet 1618085881633714179
# Unavailable user in card on tweet 1610241510666080256
# Empty user ref object in card on tweet 1610241510666080256
# User 1172224942756093952 not found in user refs in card on tweet 1610241510666080256
# User 1041604336160137216 not found in user refs in card on tweet 1610241510666080256
# Stopping after 20 empty pages

# %%
tweet_data
# Out:
# [[datetime.datetime(2023, 6, 23, 8, 13, 33, tzinfo=datetime.timezone.utc),
#   1672155919591907330,
#   '#AssamFloods update: There is no respite from the flood fury in the state, as nearly 5 lakh people are affected. Nearly 63 thousand children are said to be affected by the floods. Two people lost their lives in the last 24 hours.',
#   'airnewsalerts',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 23, 8, 3, 8, tzinfo=datetime.timezone.utc),
#   1672153301687705603,
#   'At least 496 thousand people were in the flood zone in the northeastern Indian state of Assam, where heavy rains do not stop. This is reported by the Assam Disaster Management Authority in the distributed information.\n\n#India #News https://t.co/2yC1f9XcIs',
#   'rusashanews',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 23, 7, 39, 14, tzinfo=datetime.timezone.utc),
#   1672147284879114242,
#   '@centerofright @NagpurKaRajini Jai Agniveers are being trained to protect people of India from adversaries and enemies. They will later become warriors to guard out borders from any kind of stress. They will be there  internally too to help in any kind of distress like floods, violence etc. We respect them.',
#   'niranjan_nalkur',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 23, 6, 54, 9, tzinfo=datetime.timezone.utc),
#   1672135940477730816,
#   'FLOOD SITUATION IN ASSAM WORSENS.0\n #Titanic https://t.co/1r0MFPZQMR',
#   'TheBharatIndia1',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 23, 6, 31, 59, tzinfo=datetime.timezone.utc),
#   1672130361378189319,
#   '#Assam State Disaster Management Authority (ASDMA) said a total of 4,95,799 people have been affected by floods in the state, with 1 death recorded so far. https://t.co/0Bdd2GYSl9',
#   'ians_india',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 23, 6, 21, 16, tzinfo=datetime.timezone.utc),
#   1672127665812168706,
#   'The #flood situation in #Assam showed no signs of improvement even as one person was killed due to the deluge, while nearly five lakh people were affected. \nhttps://t.co/2lDG2KmF3R',
#   'IndiaToday',
#   4,
#   2,
#   1],
#  [datetime.datetime(2023, 6, 23, 5, 21, 38, tzinfo=datetime.timezone.utc),
#   1672112656747233281,
#   'Impressive spectacle of #Sylhet Flood Plains (#Bangladesh) from Khoh Ramhah , #Sohra or #Cherrapunji (#India)\n\nCherrapunji recorded 64mm Rainfall in last 24hrs , its triple digit streak ended today 😭 https://t.co/3jFzZoBOwF',
#   'shubhamtorres09',
#   102,
#   11,
#   5],
#  [datetime.datetime(2023, 6, 23, 4, 48, 55, tzinfo=datetime.timezone.utc),
#   1672104422070009856,
#   'Flood situation in Assam grim with around five lakh people reeling under the deluge which has claimed one life so far, officials said. Major rivers of state flowing above danger level. MeT dept forecast heavy rain over next few days',
#   'PTI_News',
#   50,
#   3,
#   3],
#  [datetime.datetime(2023, 6, 23, 4, 15, 27, tzinfo=datetime.timezone.utc),
#   1672096003472900097,
#   'Floods and Landslides Kill at Least 70 in India and Bangladesh!\n\nTikTok: https://t.co/7OlTQJ3qm3\n\n#india  #bangladesh  #floods #landslides  #Jesus #endtimes #endtimessigns #jesuschrist #signsfromabove #rapture #news #breakingnews #wakeup #christiannews #faithnews #christian https://t.co/eFZLw3XyZw',
#   'signsfrom_above',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 23, 3, 10, tzinfo=datetime.timezone.utc),
#   1672079530943713281,
#   '@KenRoth There is flood of such articles in the press in last few days. Such huge is the desire and propaganda to keep india in 20th century.',
#   'imrohitpareek',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 23, 2, 41, 8, tzinfo=datetime.timezone.utc),
#   1672072264936747009,
#   'The flood situation in Assam deteriorated drastically on June 22 with one person losing his life and nearly five lakh people reeling under the deluge.\n\n#AssamFlood #flooding #rain\n\nhttps://t.co/EEn7x6QVf5',
#   'IndiaTodayNE',
#   3,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 23, 2, 24, 21, tzinfo=datetime.timezone.utc),
#   1672068043529240576,
#   'India – Over 100,000 Hit by Floods in 20 Districts of Assam\n#water\n#news\n#waternews https://t.co/ydqErDbf7m',
#   'WorldWater_News',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 23, 2, 17, 50, tzinfo=datetime.timezone.utc),
#   1672066404445732864,
#   '@SantoshMoh22786 @TheSincereDude Oh, got it. Manipur unrest, Orissa cyclone, and Assam floods, among other barking issues in India, are dogs from which the elephant walks… away.',
#   'anupamapurohit5',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 23, 0, 22, 21, tzinfo=datetime.timezone.utc),
#   1672037341488381952,
#   'Water here water there flood in Assam India 🌿 #stay safe https://t.co/SGjc7uUta9',
#   'KRanchiary',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 21, 55, 19, tzinfo=datetime.timezone.utc),
#   1672000339460120576,
#   'Dear @AmitShah after visiting Gujarat please visit them in sikkim too they are also part of India in Northeast india call seven sister..\n\nA bridge and a vegetable shed washed away by floodwaters in Chandabong Kalaz River,West Sikkim\n\n#Sikkim #flood #rains #landslides #NorthEast https://t.co/pfjybVudc0',
#   'ErAsadullah',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 21, 19, 36, tzinfo=datetime.timezone.utc),
#   1671991348272979969,
#   'Floods on Greece and in Serbia. Heavy rains and Cyclones in Southern Russia and Rajasthan, India: \n\nhttps://t.co/8xGR6dyHy4',
#   'RageWeatherNews',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 19, 13, 38, tzinfo=datetime.timezone.utc),
#   1671959649371983872,
#   '@Aki_posting paxtanis living in poor, underdeveloped, bankrupt, 14th ranked failed state called india "sheethole".....\n\n..this is why indians totally support Indian government not helping paxtans during their flood, covid and during your economic collapse. \n\nenjoy.',
#   'GJoeye_285',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 18, 2, 33, tzinfo=datetime.timezone.utc),
#   1671941760212406273,
#   'Flood situation worsens in Assam; around 45,000 people, 108 villages currently underwater   #AssamFloods #Assam #Nalbari https://t.co/sRIpOdQkIC',
#   'NCIB_INDIA_NEWS',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 17, 39, 49, tzinfo=datetime.timezone.utc),
#   1671936038435164163,
#   '@a63738464 Not much to do with USTs but India would be a good place to invest once we are in recession and central banks open the $ flood gates again. \n\nLong-term growth can ONLY come from India.',
#   'TOzgokmen',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 17, 34, 43, tzinfo=datetime.timezone.utc),
#   1671934754126716928,
#   '@PMOIndia @POTUS One news channel in India showing how well our PM is being received in USA....Next channel showing how miserably v failed in handling the floods issue AGAIN in Assam.....Our state Manipur is burning and people celebrating in USA',
#   'AlokRan65274481',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 17, 29, 22, tzinfo=datetime.timezone.utc),
#   1671933408019365888,
#   '1k Cr Spent On Drainage &amp; Flood Control In 7 Yrs, Yet Flooding Threat Looms Large | Gurgaon News - Times of India https://t.co/m9SyxzAWEj',
#   'yadav1802',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 17, 28, 51, tzinfo=datetime.timezone.utc),
#   1671933279057096705,
#   '1k Cr Spent On Drainage &amp; Flood Control In 7 Yrs, Yet Flooding Threat Looms Large | Gurgaon News - Times of India https://t.co/m9SyxzAWEj',
#   'yadav1802',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 17, 11, 17, tzinfo=datetime.timezone.utc),
#   1671928857023365120,
#   'In view of surge in temperature &amp; due to increase in discharge of water level in rivers, streams &amp; for safety/interest of general public of Kargil District, it is advised to general public to be cautious &amp;not to venture around  river banks/nallahs &amp; flood prone areas. https://t.co/NTSRCPW2e3',
#   'NorthIndiaTimes',
#   3,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 17, 5, 34, tzinfo=datetime.timezone.utc),
#   1671927420423749634,
#   'We #Salute our health workers for going beyond the call of duty to help and provide services to people in this flood situation. We are always ready to help you Anytime,Anywhere.\n\n@nhm_assam @MoHFW_INDIA https://t.co/yJj4aPaj7N',
#   'NhmNalbari',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 16, 39, 23, tzinfo=datetime.timezone.utc),
#   1671920832548048896,
#   '#VantageUSA: In #India, rain wreaks havoc in the north-eastern state of #Assam. Torrential rain leads to floods. Over 100 thousand people affected in 20 districts. \n\n@palkisu brings you more! #VantageOnFirstpost https://t.co/ebtEZr2biZ',
#   'firstpost',
#   6,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 22, 16, 14, 41, tzinfo=datetime.timezone.utc),
#   1671914614555316225,
#   '1k Cr Spent On Drainage &amp; Flood Control In 7 Yrs, Yet Flooding Threat Looms Large | Gurgaon News - Times of India https://t.co/I4jy35fCHz\nReally shameful act\nCorruption at utmost level. \n@OfficialGMDA @MunCorpGurugram @mlkhattar  @CMOHaryana @timesofindia @rakeshdaultabad',
#   'amitgarg1386',
#   0,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 22, 15, 31, 30, tzinfo=datetime.timezone.utc),
#   1671903747088306176,
#   'Floods triggered by torrential rains forced residents of villages and towns in India’s northeastern Assam state to flee their homes and take shelter on Thursday.\n\nNearly 45,000 locals were reportedly affected in Nalbari. Some were seen carrying their belongings as they waded through floodwater.',
#   'AmuTelevision',
#   1,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 22, 15, 27, 32, tzinfo=datetime.timezone.utc),
#   1671902748336590849,
#   'Nearly 120,000 people affected as flood situation in India’s Assam worsens; orange alert issued\n\n#FloodInAssam #Flood #AssamFloods #assamrains #Assam #alert #ASDMA #news  #Newsnight #NewsBreak #NewsUpdates #NewsZERO \n\nhttps://t.co/snlSIztWkk',
#   'india_weekly',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 15, 27, 31, tzinfo=datetime.timezone.utc),
#   1671902746872623111,
#   "@SammichArtisan @kylecordes @jonahdavids1 Haven't catastrophic floods been happening in India for thousands of years?",
#   'DDAndrews',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 15, 5, tzinfo=datetime.timezone.utc),
#   1671897078077718528,
#   '#AssamFloods : 4.95 lakh people reeling under fury of floods in 22 districts, One dead\n\nhttps://t.co/AsJtTOALiY',
#   'airnewsalerts',
#   13,
#   6,
#   0],
#  [datetime.datetime(2023, 6, 22, 14, 29, 14, tzinfo=datetime.timezone.utc),
#   1671888076849967105,
#   'While MTG-Boebert are having a stupid cat fight on impeachment (which is never happening in a +4 seat GOP House), Biden is playing for keeps\n\nBiden is loosening migration rules for India, allowing hundreds of thousands of Indian migrants to flood into jobs.\n\nOne side plays to win https://t.co/AJHmFc4u1j',
#   'RecoverRepub',
#   7,
#   1,
#   1],
#  [datetime.datetime(2023, 6, 22, 14, 4, 49, tzinfo=datetime.timezone.utc),
#   1671881932400115712,
#   "Under the guidance of Hon'ble Union Minister, #MoES, Shri @KirenRijiju, India won the first #PMC chair to oversee the implementation of the Flash Flood Guidance System (FFGS) at global level.\n\nThe election was held on June 16, 2023, in Skopje, North Macedonia. About 17 FFGS",
#   'TradeInvest_365',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 14, 2, 41, tzinfo=datetime.timezone.utc),
#   1671881394568716290,
#   "Under the guidance of Hon'ble Union Minister, #MoES, Shri @KirenRijiju, India won the first #PMC chair to oversee the implementation of the Flash Flood Guidance System (FFGS) at global level.\n\nThe election was held on June 16, 2023, in Skopje, North Macedonia. About 17 FFGS",
#   'moesgoi',
#   27,
#   11,
#   2],
#  [datetime.datetime(2023, 6, 22, 13, 59, 4, tzinfo=datetime.timezone.utc),
#   1671880486258634752,
#   'India – Over 100,000 Hit by Floods in 20 Districts of Assam @Flood_List https://t.co/8qoIpBCMly https://t.co/Q0HOl1kvKJ',
#   'kwbworld',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 13, 57, 36, tzinfo=datetime.timezone.utc),
#   1671880115444420608,
#   'A scene of flood in Assam India https://t.co/yrRxlKL0PI',
#   'KRanchiary',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 13, 46, 18, tzinfo=datetime.timezone.utc),
#   1671877274797490180,
#   'Monsoon wreaks havoc in Arunachal Pradesh, causing floods, landslides, and road blockades. Rising rivers and heavy rainfall disrupt normal life. \n\n#MonsoonAlert #ArunachalFloods #RoadDisruptions\n\nhttps://t.co/zYQuN7qlZl https://t.co/QmKgtW2aqV',
#   'IndiaTodayNE',
#   8,
#   3,
#   0],
#  [datetime.datetime(2023, 6, 22, 12, 55, 34, tzinfo=datetime.timezone.utc),
#   1671864504550916098,
#   'Assam: Power Minister Nandita Garlosa conducted a thorough inspection of flood-affected areas in Baksa district, offering support to victims. \n\n#FloodRelief   #AssamFloods\n\nhttps://t.co/WONPdEbMmb',
#   'IndiaTodayNE',
#   6,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 12, 41, 3, tzinfo=datetime.timezone.utc),
#   1671860853656756224,
#   'Over one lakh people in 20 districts, affected by floods in Assam. The flood situation is getting worse. India Meteorological Department in Guwahati has predicted heavy rainfall in the state over the next few days. #AssamFloods #heavyrain #IMD https://t.co/cHbhgfoTKh',
#   'eglobalnews23',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 10, 54, 33, tzinfo=datetime.timezone.utc),
#   1671834050716213249,
#   'Flood, which flooded 108 villages in India, affected more than 115,000 people #INDIA #More_Than #People #Than https://t.co/C3YHKcvNd3',
#   'IdeallyaNews',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 10, 54, 24, tzinfo=datetime.timezone.utc),
#   1671834014422794240,
#   'India – Over 100,000 Hit by Floods in 20 Districts of Assam https://t.co/kuPJRoqnDe via @FloodList \n\nFloods and landslides also reported in Sikkim and Meghalaya. https://t.co/zyXpKHtYEJ',
#   'FloodList',
#   2,
#   3,
#   0],
#  [datetime.datetime(2023, 6, 22, 10, 54, 10, tzinfo=datetime.timezone.utc),
#   1671833954687815680,
#   'Torrential rains have worsened the flood situation in #Assam, with over one lakh people affected.  \n\n#Nalbari has borne the biggest brunt, with 45,000 reeling under inundation, followed by #Baksa (26,500), and #Lakhimpur (25,000), as per #ASDMA data. \n\n#AssamFloods https://t.co/DM613lrThb',
#   'league_of_india',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 10, 45, 18, tzinfo=datetime.timezone.utc),
#   1671831721807839232,
#   'Authorities confirmed that the\xa0flood in Assam remained grave on Wednesday, with almost 1.20 lakh people affected by the downpour across 20 districts.\n\n#Assam #Floods #disastermanagement #latestnews #India #ASDMA https://t.co/Laq2HgOGL5',
#   'TenNewsDotIn',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 10, 28, 27, tzinfo=datetime.timezone.utc),
#   1671827480607588357,
#   'Amour-propre\n\nManipur Burning - 115+ People Died\nAssam Flood - Nearly 1.20 lakh People in 20 Districts Affected\n\nIn America - Prime Minister of India Enjoyed Dinner with 𝐌𝐚𝐫𝐢𝐧𝐚𝐭𝐞𝐝 𝐌𝐢𝐥𝐥𝐞𝐭, 𝐒𝐭𝐮𝐟𝐟𝐞𝐝 𝐌𝐮𝐬𝐡𝐫𝐨𝐨𝐦𝐬 &amp; 𝐑𝐢𝐬𝐨𝐭𝐭𝐨\n\n#ModiInAmerica https://t.co/YE0KFnmEnC',
#   'tanmoyofc',
#   10,
#   5,
#   1],
#  [datetime.datetime(2023, 6, 22, 10, 15, 11, tzinfo=datetime.timezone.utc),
#   1671824143225077761,
#   '#AssamFloods worsen, 1.2 lakh hit in 20 districts\n\nA total of 1,280 people have been evacuated by boats deployed by disaster management agencies in the last 24 hours, as NDRF and SDRF rescuers have fanned out to combat the flood situation.\n\nRead: https://t.co/KSaWEFMVAB https://t.co/eM6SW4SYYS',
#   'timesofindia',
#   175,
#   41,
#   6],
#  [datetime.datetime(2023, 6, 22, 10, 13, 12, tzinfo=datetime.timezone.utc),
#   1671823645398761472,
#   'Authorities confirmed that the\xa0flood in Assam remained grave on Wednesday, with almost 1.20 lakh people affected by the downpour across 20 districts.\n\n#Assam #Floods #disastermanagement #latestnews #India #ASDMA https://t.co/Z59ciGtLiy',
#   'TenNewsDotIn',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 9, 53, 26, tzinfo=datetime.timezone.utc),
#   1671818671097024512,
#   'Flood in Bilpar Assam India 🌿\nGood Evening nice weekend 🌻 https://t.co/6UIKS3MJjZ',
#   'KRanchiary',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 9, 30, tzinfo=datetime.timezone.utc),
#   1671812774153043969,
#   '#MiddayNews |\n\nAssam flood: Situation worsens in several districts, nearly 1.2 lakh people affected\n\n#Assam #Flood #India #NewsUpdate \n\nhttps://t.co/Qt5ejVsSyw',
#   'mid_day',
#   1,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 22, 9, 18, 16, tzinfo=datetime.timezone.utc),
#   1671809820217974785,
#   'Torrential rains have worsened the flood situation in #Assam, with over one lakh people affected.\n\nNalbari bears the brunt, with 45,000 reeling under inundation, followed by Baksa (26,500) & Lakhimpur (25,000), as per ASDMA data.\n\n#AssamFloods\n\nRead: https://t.co/9mTRvCO1Qc\n\n📸: IANS',
#   'weatherindia',
#   6,
#   3,
#   0],
#  [datetime.datetime(2023, 6, 22, 9, 3, 33, tzinfo=datetime.timezone.utc),
#   1671806116442038273,
#   '#WATCH | #Assam: Several areas of Barama town in Baksa district face severe waterlogging and flood-like situation due to incessant rainfall in the region. \n\n#AssamFloods https://t.co/QLw8SoVQvI',
#   'NewsMobileIndia',
#   1,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 22, 8, 59, 26, tzinfo=datetime.timezone.utc),
#   1671805081493069824,
#   'Nearly 1.2 lakh people affected as flood situation remains grim in Assam\n\nhttps://t.co/samoaHUdWi',
#   'ThePrintIndia',
#   5,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 22, 8, 24, 9, tzinfo=datetime.timezone.utc),
#   1671796202738954241,
#   '#Assam flood woes: Over 27,000 people from 63 villages were affected in the Baksa district. #India https://t.co/YKMPTEkaYn',
#   '1_meghana',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 8, 12, 6, tzinfo=datetime.timezone.utc),
#   1671793166737985537,
#   'VIDEO | Large swathes of land inundated in Assam as flood situation worsens in the state; nearly 1.2 lakh people affected in 10 districts. https://t.co/shAlAYIg3m',
#   'PTI_News',
#   50,
#   19,
#   3],
#  [datetime.datetime(2023, 6, 22, 8, 7, 42, tzinfo=datetime.timezone.utc),
#   1671792062814093312,
#   '@RoadknightThe Fact: Aboriginals in Victoria told settlers that the original inhabitants we wiped out in the great flood, and that their ancestors came from across the sea from the North West (India way)',
#   'RED_RAM66',
#   4,
#   2,
#   2],
#  [datetime.datetime(2023, 6, 22, 7, 40, 22, tzinfo=datetime.timezone.utc),
#   1671785184331718656,
#   '#Assam: Nearly 1.20 lakh people in 20 districts affected by floods\n\n#AssamFloods \n\nhttps://t.co/gkGL9h46py https://t.co/ZhH5VM8a9Y',
#   'BiIndia',
#   13,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 22, 7, 35, 45, tzinfo=datetime.timezone.utc),
#   1671784019867095040,
#   'આસામમાં ભારે વરસાદ-પૂરને લીધે 800 ગામડાં જળમગ્ન - India News Gujarat\n#heavyrain #assam #flood #village #weatherupdate #IndiaNewsGujarat #Gujaratnews #TodayGujratiNews\nhttps://t.co/AC11JTheST',
#   'in_gujarati',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 7, 29, 18, tzinfo=datetime.timezone.utc),
#   1671782397107470336,
#   'Assam Water Resources Minister Pijush Hazarika on June 22 asserted that the flood situation in Upper Assam has been reduced to a great extent.\n\n#assam #floods #upperassam\n\nhttps://t.co/P8i54CENdi',
#   'IndiaTodayNE',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 7, 28, 24, tzinfo=datetime.timezone.utc),
#   1671782170397138944,
#   'Assam Flood Worsens, Over One Lakh People In 20 Districts Affected \n\n#Assam #AssamFloods \n\nhttps://t.co/t1GZIRbNDG',
#   'NewsMobileIndia',
#   1,
#   4,
#   0],
#  [datetime.datetime(2023, 6, 22, 7, 16, 7, tzinfo=datetime.timezone.utc),
#   1671779080575008768,
#   '#WeatherUpdate ⛈️☀️| The #monsoon is likely to reach Mumbai by June 24 \n\n#Heatwave conditions over East &amp; Central India are likely to abate from June 23.\n\nThe #flood situation worsens in Assam, 44,000 people affected in #Nalbari district\n\nhttps://t.co/qjH8iHOV2w',
#   'CNBCTV18News',
#   1,
#   3,
#   0],
#  [datetime.datetime(2023, 6, 22, 7, 7, 51, tzinfo=datetime.timezone.utc),
#   1671777001034612737,
#   '#Flood situation in #Assam deteriorated further with more areas being inundated due to an upsurge in the water levels as torrential rain continued to lash.  \n\nNalbari is currently the worst-hit with almost 45,000 people reeling under flood waters, followed by Baksa (26,500) & Lakhimpur (25,000), according to the ASDMA.\n\n#FloodInAssam #AssamFloods #ASDMA',
#   'ians_india',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 6, 5, 20, tzinfo=datetime.timezone.utc),
#   1671761266245881857,
#   'The incidents, which occurred in the Malda district, also claimed the lives of nine cattle.\n\n#theSun #theSundaily #flood #rainfall #India https://t.co/mEWlF7D9AF',
#   'theSundaily',
#   0,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 22, 5, 50, 57, tzinfo=datetime.timezone.utc),
#   1671757645160513537,
#   'The flood situation in #Assam worsened severely on Wednesday, which has already affected nearly 1.2 lakh people across 10 districts of the state. \n\nhttps://t.co/JSqcoIZ5l9',
#   'IndiaToday',
#   3,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 5, 37, 37, tzinfo=datetime.timezone.utc),
#   1671754293609922561,
#   'Flood situation worsens in Assam; around 45,000 people, 108 villages currently underwater\n\nhttps://t.co/MJScv9mrrO\n\n#NewsCapital #Assam #AssamFloods #FloodInAssam #Flood #India',
#   'thenewscapital',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 5, 37, 36, tzinfo=datetime.timezone.utc),
#   1671754288467677184,
#   'Flood situation worsens in Assam; around 45,000 people, 108 villages currently underwater\n\nhttps://t.co/MJScv9mrrO \n\n#NewsCapital #Assam #AssamFloods #FloodInAssam #Flood #India https://t.co/STHA82HIC0',
#   'thenewscapital',
#   1,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 22, 5, 33, 22, tzinfo=datetime.timezone.utc),
#   1671753224171433985,
#   'Flood situation worsens in Assam’s Nalbari: 45,000 people across 108 villages affected\nhttps://t.co/0rJrgDafr5',
#   'OpIndia_com',
#   29,
#   9,
#   0],
#  [datetime.datetime(2023, 6, 22, 5, 25, tzinfo=datetime.timezone.utc),
#   1671751115376046080,
#   '#Assam: 1.2 lakh people affected due to floods in 17 districts.\nhttps://t.co/NnRL9dCdof',
#   'airnewsalerts',
#   14,
#   7,
#   0],
#  [datetime.datetime(2023, 6, 22, 4, 57, 12, tzinfo=datetime.timezone.utc),
#   1671744121604567041,
#   'Flood situation grim in Assam; nearly 1.2 lakh hit\n\nhttps://t.co/pttqDvd534 https://t.co/93fVbVw38X',
#   'PTI_News',
#   151,
#   15,
#   6],
#  [datetime.datetime(2023, 6, 22, 4, 52, tzinfo=datetime.timezone.utc),
#   1671742813514485760,
#   'The flood situation in Assam worsened dramatically on June 21, with about 1.2 lakh people stranded across ten districts.\n\n#AssamFlood #district #disaster\n\nhttps://t.co/WO0rye9D50',
#   'IndiaTodayNE',
#   3,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 22, 4, 45, 47, tzinfo=datetime.timezone.utc),
#   1671741248762421251,
#   '1950 ::  Flood In Assam \n\nHuts, Trees And Highways Submerged \n\n(Photo Division ) https://t.co/thfmj9YshU',
#   'IndiaHistorypic',
#   216,
#   13,
#   2],
#  [datetime.datetime(2023, 6, 22, 4, 40, 37, tzinfo=datetime.timezone.utc),
#   1671739948956004352,
#   "This is a yearly reminder for 'Distance from Delhi Editor/s' who bemoan the lack of media coverage of floods in north east India. The reportage and visuals from Assam is in your newsroom via ANI. Use it in your bulletins.",
#   'smitaprakash',
#   315,
#   47,
#   10],
#  [datetime.datetime(2023, 6, 22, 4, 27, 31, tzinfo=datetime.timezone.utc),
#   1671736650827800577,
#   '#AssamFlood: Pohumara and Kaldia are the main rivers that flow through Bajali and its nearby areas. But due to incessant rainfall, the water level of both rivers is currently flowing above the danger level, which causes floods in Bajali and adjacent areas.\nhttps://t.co/4RG1LstYJS',
#   'IndiaTodayNE',
#   2,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 4, 22, 8, tzinfo=datetime.timezone.utc),
#   1671735294343692288,
#   'Flood situation in Assam grim as incessant rains in several parts of state inundated new areas with 1.2 lakh people affected in 10 districts, said official bulletin',
#   'PTI_News',
#   38,
#   5,
#   0],
#  [datetime.datetime(2023, 6, 22, 4, 5, 36, tzinfo=datetime.timezone.utc),
#   1671731136995930112,
#   '@sarbanandsonwal @PIB_India @DDNewslive @MIB_India @moayush @mdniy Hello! Sir.  Wanted to draw your attention to the current flood situation in Assam. Please approach the required authorities and do the needful for us. A permanent solution to this problem needs to be found out.  We admire you and are hopeful that you will do justice to us.',
#   'ShrutiK29156',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 3, 40, 59, tzinfo=datetime.timezone.utc),
#   1671724940645777408,
#   "@Dianne__LadyD @deborah_saffer @JWPowerYourLife @angiepo97112888 @AuthorMBTosi @KariJoys @KellieAnnOxford @nancymurden @woodywigmore @anonymous6969s @Isabelmouton @jaghuara @MargoCarr13 If you look around New R coming Floods in India\nEqually Heatwaves killing Pple\nIn between Corrupted Living\nOn Whose cost?\nCorrupt may escape for a while\nCURSES from They R not Free\nSooner They'll Suffer with Denied Right2live Poor Society\nTheirForts'll fall\nWithTheCURSESofVictims",
#   'ushinedatme',
#   2,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 22, 3, 21, 3, tzinfo=datetime.timezone.utc),
#   1671719924862001152,
#   'Assam flood 2023 Nearly 1.20 lakh people in 20 districts affected latest updates Beki River water level danger mark https://t.co/hlrvPWPSiQ \nhttps://t.co/hlrvPWPSiQ',
#   'Realtime_india',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 22, 1, 42, 23, tzinfo=datetime.timezone.utc),
#   1671695091516448768,
#   '#INSURANCE\nAgriculture in India is highly susceptible to risks like droughts and floods. It is necessary to protect the farmers....  @ Rs.290\nBLUEROSE STORE\nhttps://t.co/IjdqUZtznt\n\nAMAZON\nhttps://t.co/8pDjBcOVgO\n\nFLIPKART\nhttps://t.co/tRtRQ3KTbu https://t.co/DteE0gxpTj',
#   'RanaJagendra',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 21, 37, 26, tzinfo=datetime.timezone.utc),
#   1671633451475140608,
#   '@AJEnglish A "PEE N U FLOOD IT" SIZE QATAR  IS NOT EVEN A STREET CORNER IN A SMALL TOWN ANYWHERE IN INDIA... INDIA HAS CHANGED SINCE 2014 N CAN KICK BUTT',
#   'SanjaiJoshi10',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 18, 46, tzinfo=datetime.timezone.utc),
#   1671590306893164546,
#   "@Kritiitweetss many ppl don't know him even in Pakistan and he is portrayed as terrorist but no one tell how many services he has. He along with his foundation helped poor everytime in floods earthquakes etc.india labelled him terrorist because he raise voice against cruelty with Kashmiris . https://t.co/uMzyl3TgMk",
#   'KHADBRA',
#   8,
#   0,
#   4],
#  [datetime.datetime(2023, 6, 21, 18, 10, tzinfo=datetime.timezone.utc),
#   1671581246026129433,
#   '@mdpollak Cockburn years ago did a wonderful piece on these exchange rates. 400 people in India drowned in a flood == one English teenager in Liverpool who got a bad teacher.',
#   'anacharsis',
#   2,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 21, 17, 9, 29, tzinfo=datetime.timezone.utc),
#   1671566018630782978,
#   '@PemaKhanduBJP @PMOIndia @MDoNER_India @adgpi @DefenceMinIndia Please ban single-use plastic in the above mentioned places.🙏 Otherwise Arunachal will flood before tourism becomes a thing over there. #HighPriority',
#   'Bhavna_Sharma1',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 17, 5, 24, tzinfo=datetime.timezone.utc),
#   1671564989327343631,
#   'RSOE EDIS Event Report - Flood - India - Flood situation worsens in Assam, nearly 1.2 lakh people hit - https://t.co/v3BhSXOoNl',
#   'RSOE_EDIS',
#   0,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 21, 17, 0, 44, tzinfo=datetime.timezone.utc),
#   1671563816679636994,
#   '@nsitharaman @nsitharamanoffc Madam EPR introduced by Govt. Of India in the name of Pollution control has opened flood gates of corruption for Customs. Request your urgent attention. @PiyushGoyalOffc @PiyushGoyal. Every exporter and Importer has to pay. @narendramodi',
#   'SaintSudeep',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 16, 46, 10, tzinfo=datetime.timezone.utc),
#   1671560151445442560,
#   '#Sikkim CM #PremSinghTamang met people affected by flash floods in Uttarey, Geyzing and distributed relief materials to them\n\nRight now the roads are completely closed, we will get them opened soon. We have given relief after the report of the district administration. https://t.co/BX8UFOfW9i',
#   'NewsMobileIndia',
#   0,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 21, 16, 33, 13, tzinfo=datetime.timezone.utc),
#   1671556891963715584,
#   'Schools,  Closed in Broward; Flood Warning Extended After Massive rain in Tamulpur Assam, India 🇮🇳\n\nTELEGRAM JOIN 👉https://t.co/noX4cUUkWk https://t.co/2HGFVi3DSl',
#   'Discoverynewson',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 16, 21, 38, tzinfo=datetime.timezone.utc),
#   1671553975534104576,
#   '@WSJ Manipur in India is burning, violence in West Bengal, floods in Assam and the prime minister had not spoken about these incidents till now',
#   'GAK1966',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 15, 33, 3, tzinfo=datetime.timezone.utc),
#   1671541751251861504,
#   'Flood situation worsens in Assam, nearly 1.2 lakh people hit #India #AssamFloods  https://t.co/8LYX5T4doL',
#   'mathrubhumieng',
#   2,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 21, 15, 29, 30, tzinfo=datetime.timezone.utc),
#   1671540856875274240,
#   'Comm/Secy, I&amp;FC @sahuajeet takes stock of flood control measures in #Leh town, emphasizes nallah cleaning &amp; structural measures to minimize flood risks in the region.\n\nRead more: https://t.co/4d8xxWPC9q\n\n@lg_ladakh \n@MoJSDoWRRDGR \n@PIBHomeAffairs \n@MoHUA_India \n@NDRFHQ https://t.co/jMTUFRJ4Ev',
#   'DIPR_Leh',
#   12,
#   1,
#   1],
#  [datetime.datetime(2023, 6, 21, 15, 24, 5, tzinfo=datetime.timezone.utc),
#   1671539493793562630,
#   '1.  "🌧️ The flood condition in Assam, India, remains critical due to overnight rainfall. Over 34,000 people across nine districts of the state are affected by the floods. #AssamFloods #India"',
#   'ROH1T_',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 21, 15, 10, 40, tzinfo=datetime.timezone.utc),
#   1671536118448390144,
#   '@santobartez A complete migration story to Turkey from ancient India after the flood at Xanthos. Esen River identified Essenes of the Bible and Issan of the Indian puranas in the region of Mt.Tauros involved in the flood story.',
#   'AkhilKumarSaho8',
#   5,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 14, 53, 14, tzinfo=datetime.timezone.utc),
#   1671531729964654593,
#   '@aestheticayush6 @narendramodi India was reeling under cyclone, Flood 🌀, pappu was busy defaming India in US.',
#   'NickBrahm',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 14, 10, 22, tzinfo=datetime.timezone.utc),
#   1671520941279420420,
#   "🌍Today in 60 Seconds: Anadolu's top stories\n\n• Ukraine Recovery Conference begins in London\n\n• Death toll from floods caused by Kakhovka dam explosion rises to 41\n\n• India, Türkiye's purchases of Russian S-400s are different cases, says Pentagon https://t.co/vBgbGul2EG",
#   'anadoluagency',
#   3,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 13, 36, 1, tzinfo=datetime.timezone.utc),
#   1671512297158631425,
#   '#Assam: #ASDMA refutes media reports claiming water release from #Bhutan dam causing flood in state \nhttps://t.co/0XywDRLvMX',
#   'IndiaTodayNE',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 13, 31, 39, tzinfo=datetime.timezone.utc),
#   1671511198825627649,
#   'Remnants of Cyclone Biparjoy leave a trail of destruction in Rajasthan and record rainfall in Chennai, India https://t.co/UBEsN93dQb #flood #Rajasthan #Chennai #WXrecord #CycloneBiparjoy #Biparjoy',
#   'TheWatchers_',
#   4,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 21, 13, 21, 55, tzinfo=datetime.timezone.utc),
#   1671508747460411393,
#   '#Ajmer is grappling with a #Flood -like situation as the city experiences #heavyrainfall. The downpour has led to overflowing rivers, waterlogging, and disrupted normal life in several areas\n#AjmerFlood #CycloneBiparjoy https://t.co/5Ba9UTjKuQ',
#   'IndiaObservers',
#   1,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 21, 12, 38, 13, tzinfo=datetime.timezone.utc),
#   1671497752642035714,
#   '@AnasBaddyr @GaryLineker That is, if you ignore the current heatwave we are experiencing, the recent floods in Pakistan, and the heatwave in India, particularly Uttar Pradesh, and the pacific islands being submerged',
#   'MichaelWaldhei3',
#   2,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 21, 12, 28, 30, tzinfo=datetime.timezone.utc),
#   1671495306452643841,
#   'These maps use data from the #RCMSatellites, #TerraSARX and ResourceSat-2 to estimate flood areas in Kachchh district, India, after #CycloneBiparjoy: https://t.co/4x4srnNfj9 https://t.co/ILSZUF4EFK',
#   'DisastersChart',
#   8,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 21, 11, 37, 52, tzinfo=datetime.timezone.utc),
#   1671482564295680000,
#   'This brings me to another opportunity lying in plain sight. Buying stocks of companies that are supplying turnkey drip irrigation systems to farmers. India still largely uses flood irrigation to grow its crops. Area under drip is just 6% and the center is providing 100% subsidies',
#   'BoyBaked',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 21, 10, 53, 6, tzinfo=datetime.timezone.utc),
#   1671471299225329664,
#   'Indiametdept: Shri. Rahul Saxena, Focal Point (SASIAFFGS), Regional Centre, India has won the election to the Chair of the First Project Management Committee (PMC) of the Global Flash Flood Guidance System Program of WMO (2023 - 2027).\n\n@WMO @USAID @CREW… https://t.co/9yI9gBBQv2',
#   'DataBanks_In',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 10, 47, 16, tzinfo=datetime.timezone.utc),
#   1671469830497779712,
#   "@RobertJudd4 @Kalimeralynn @UnityNewsNet @Irene48 You give to India especially to Christian missionaries operating in India to convert people during earth quakes,floods etc not to indian government.. \n\nIndian government won't take any aid(expect it did during corona, it gave aid &amp; took aid too during different waves of corona.) https://t.co/q8bNxSjo59",
#   'Zakirranga',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 21, 8, 47, 50, tzinfo=datetime.timezone.utc),
#   1671439772877815808,
#   "@SophyRidgeSky @Bella_healtheco Somehow no one talks about uninhabitable 50c temperatues in Iran and India, warm seas losing oxygen and millions of fish dying. Fires, floods and disappearing artic ice. This is the DON'T LOOK UP disaster in our face. But hey poor lawless immoral corrupt lying charlatan ah....",
#   'PaulBasnett',
#   2,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 8, 41, 34, tzinfo=datetime.timezone.utc),
#   1671438195093823492,
#   "Gurugram's annual floods phenomena, explained! https://t.co/SS0HF1CJtl \n\nIn fact, the city of Gurugram in Haryana, which is part of the Delhi NCR region, is surrounded by the Aravalli hills from three sides, the whole city is situated on a slope. The height of Gwalpahari area near Delhi border is 290 meters above sea level, while the lowest area near Najafgarh drain is 200 meters above sea level i.e. 90 meters difference. Water flows from the higher region and collects in the lower areas, that cause floods.",
#   'GReportIndia',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 8, 37, 16, tzinfo=datetime.timezone.utc),
#   1671437114863652866,
#   '@_Priyansha__ U got it all wrong!\n1st pic/tweet complaining abt high import tariff (for FULLY BUILT luxury cars) is STILL an issue 4 Tesla…Modi’s not wavering on that, as it wud flood China made Teslas into India. \nModi always asked Elon to MANUFACTURE IN India, which Elon is finally willing',
#   'OmniCurious',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 21, 8, 9, 32, tzinfo=datetime.timezone.utc),
#   1671430136665870341,
#   'In Assam, flood is one of the primary reasons behind backwardness &amp; underdevelopment as compared to mainland India. Every year because of flood many students lost track from studies, roads &amp; houses get devastated. (1/n)\n#assamfloods \n@himantabiswa @narendramodi @AmitShah',
#   'itis_hrishikesh',
#   1,
#   0,
#   1],
#  [datetime.datetime(2023, 6, 21, 7, 51, 26, tzinfo=datetime.timezone.utc),
#   1671425580640632832,
#   '#CycloneBiparjoy effect: #Rajasthan received 92.09 mm of rain against the average of 28.74 mm -- an excess of 220%, according to Met Department officials.\n\nThe cyclone-triggered torrential rainfall led to floods in the districts of Barmer, Jodhpur, Pali, Sirehi and Jalore. https://t.co/M4sDypnoVU',
#   'ians_india',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 7, 50, 57, tzinfo=datetime.timezone.utc),
#   1671425459119337472,
#   '📹 Horror as 🇷🇺 Bus Flipped by Fatal Flood - 18+\n\nThe mountainous southern region of Ossetia was inundated by rain, causing severe flooding in many areas.  \n\nA driver overestimated his ability to navigate a washed out road, resulting in the death of one passenger. https://t.co/0YeGayG7js',
#   'RT_India_news',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 7, 48, 57, tzinfo=datetime.timezone.utc),
#   1671424954016079873,
#   '@AmitShah Manipur burning , Assam @CMOfficeAssam flooded, next flood will be in Bihar @NitishKumar .\nWhat a development across India.',
#   'raj070775',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 7, 12, 23, tzinfo=datetime.timezone.utc),
#   1671415751033638912,
#   "Dam breach: Russia says it declined UN help in flood zone over 'security concerns' - Times of India\nhttps://t.co/DIOxODsML4",
#   'YouthChronical',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 6, 44, 56, tzinfo=datetime.timezone.utc),
#   1671408842746515457,
#   '@ShardulSharma1 @pathofwisdom07 @WhateverVishal @GabbbarSingh @India_Progress That’s because South Mumbai got very less rain in compared to other parts on July 26,2005 , just 73 mm . All Mumbaikars remember it as a bad event because it was catastrophic event for most of Mumbai but not for South Mumbai and that’s why it didn’t flood https://t.co/H7FuSvab4H',
#   'Utkarsh7171',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 6, 42, 12, tzinfo=datetime.timezone.utc),
#   1671408158810726401,
#   '#Haryana : Water-logging was seen at Narsinghpur Chowk due to heavy rains in #Gurugram #Rain #Flood #India #haryana https://t.co/MjJYulSWcI',
#   'DeshmukhHarish9',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 6, 41, 36, tzinfo=datetime.timezone.utc),
#   1671408004397400064,
#   'Waterlogging in parts of #Gurugram after heavy #rainfall (Visuals from #NarsinghpurChowk) \n\n#Gurugram #Rain #Flood #India #haryana https://t.co/29b9YoHJ5E',
#   'DeshmukhHarish9',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 6, 16, 40, tzinfo=datetime.timezone.utc),
#   1671401733204119555,
#   "@pathofwisdom07 @WhateverVishal @GabbbarSingh @India_Progress Sirji please Google. You will easily find how much rains Bombay gets in July and early August. Sirji in July 2005 great floods, Mumbai got 1000mm of rains in a day. Even then south Bombay didn't flood. You know what 1000mm means?",
#   'ShardulSharma1',
#   1,
#   0,
#   2],
#  [datetime.datetime(2023, 6, 21, 5, 24, 38, tzinfo=datetime.timezone.utc),
#   1671388636108017664,
#   'The flood condition in #Assam deteriorated marginally on Tuesday, with nearly 34,000 people reeling under the impact of the deluge across nine districts, according to an official bulletin.\n\nhttps://t.co/Tt84TKyR4c',
#   'IndiaToday',
#   8,
#   3,
#   0],
#  [datetime.datetime(2023, 6, 21, 5, 14, 2, tzinfo=datetime.timezone.utc),
#   1671385967494676480,
#   'The flood condition in Assam deteriorated marginally on June 20, with 34089 people reeling under the impact of the deluge across nine districts.\n\n#assam #flood #ASDMA\n\nhttps://t.co/xmxLuz8T02',
#   'IndiaTodayNE',
#   2,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 21, 4, 58, 34, tzinfo=datetime.timezone.utc),
#   1671382076887810048,
#   'Indians have the potential to flood with non-deterrent, non-exploitative influence (=soft power) in global south like Chinese goods/food culture in india.\n    \nIndian teachers should seek jobs in other countries as well like IT &amp; medical.',
#   'DialecticDude',
#   3,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 4, 34, 37, tzinfo=datetime.timezone.utc),
#   1671376049714925568,
#   "#mogambojackpots housewife value pick no.57 dated 21 June 2023 is #bankofmahastra my housewife investor friend tells me this will be a 10bagger and will double my money within a year due to digital transformation in india. This bank is flood is flooded with money over money and no one has noticed it for the last 3 years only small retail investors are jumping in and out for small profits. I recently received some money from my employers so decided to finally buy 10000 shares today and I will hold it for long term 50/75/100 targets  short term can see 35/40/45 within 3 months because of my friends 1,2, ka 4 formula. You calculate and double check if you don’t believe her. which my investor friend say invest and patiently wait   for your money to grow 3x here. With 12-15 months. If you win some profits then we all we all will salute in any of the future wealth management seminars I invite her to talk. She is not good in English as she studied in a vernacular school but is a genius and a wizard. Good luck with your investments \n\nBank of Maharashtra is engaged in providing banking services. The Bank's segments include Treasury, Corporate/Wholesale Banking, Retail Banking and Other banking operations.\nKEY POINTS \nRatios\nCapital Adequacy Ratio - 16.15%\nNet Interest Margin - 3.28%\nGross NPA - 3.74%\nNet NPA - 0.88%\nCASA Ratio - 56.08%\nBranch Network\nPresently, the bank operates a branch network of 2029 branches and 1,850 ATMs across India. Majority (33%) of branches are located in rural areas.\nLoan Book\nCorporate & others category consists of 39% of loan book, followed by retail (26%), MSME (19%) and agriculture (16%).\nExposure\nThe bank has the maximum exposure to agriculture industry with 15.1% exposure, followed by housing (14%), Infrastructure (11%), trade (8.6%), NBFC (4.4%), professional services (4.4%), HFCs (3.5%) and others.\nMETCO\nMaharashtra Executor & Trustee Company Pvt Ltd (METCO) is the 100% subsidiary of the bank. It provides auxiliary services to banking such as consultation, drafting & execution of will, management of investments, guardianship of minor's property, consultation for sale/purchase of property, etc.\nEquity Issues\nThe bank has issued major equity to Government of India in the last 3 years. It issued 130 crore equity shares[7] to central government in FY18 and ~300 crore equity shares in FY20.\nCentral Government was also issued 73 crore equity shares of the bank in August 2020 at a price of ₹11.29 per share.\nThe shareholding of the central government went up from 81.6%[7] in FY17 to 93.3% in FY21 in the bank",
#   'ArunSadanandPai',
#   0,
#   0,
#   2],
#  [datetime.datetime(2023, 6, 21, 4, 33, 13, tzinfo=datetime.timezone.utc),
#   1671375697133330432,
#   'More video of Flood like situation in Ajmer.\n#ajmer #Rajsthan #CycloneAlert #India #flashflood #Rains https://t.co/SiB5oqSHyO',
#   'AnilKumarVerma_',
#   3,
#   1,
#   0],
#  [datetime.datetime(2023, 6, 21, 4, 29, 1, tzinfo=datetime.timezone.utc),
#   1671374638067363842,
#   'Flood like situation after heavy rains in Ajmer.\n#ajmer #Rajsthan #CycloneAlert #India #flashflood #Rains https://t.co/PLRFgRhkwK',
#   'AnilKumarVerma_',
#   2,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 4, 19, 40, tzinfo=datetime.timezone.utc),
#   1671372286056894464,
#   'According to the daily #flood report of the Assam State Disaster Management Authority-ASDMA, more than 30,700 people are hit due to floods in Chirang, Darrang, Dhemaji, Dhubri, Dibrugarh, Kokrajhar, Lakhimpur, Nalbari, Sonitpur and Udalguri districts. More-https://t.co/SdKIB39Xdx',
#   'SeedsIndia',
#   3,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 4, 9, 38, tzinfo=datetime.timezone.utc),
#   1671369761316298752,
#   'Waterlogging in parts of Gurugram after heavy rainfall.\n\n#Gurugram. #Rain #Flood #India #haryana \nhttps://t.co/nHEbtW0foO',
#   'ChaudharyParvez',
#   7,
#   2,
#   0],
#  [datetime.datetime(2023, 6, 21, 4, 8, 55, tzinfo=datetime.timezone.utc),
#   1671369580525002753,
#   'Haryana: Water-logging was seen at Narsinghpur Chowk due to heavy rains in #Gurugram.\n#Rain #Flood #India #haryana \n\nhttps://t.co/jH0uIf7shF',
#   'ChaudharyParvez',
#   3,
#   3,
#   0],
#  [datetime.datetime(2023, 6, 21, 2, 12, 44, tzinfo=datetime.timezone.utc),
#   1671340342526767104,
#   "@kind_inkind @PeterHotez India and a useless product made in China? There might be. It's not impossible.",
#   'garret_flood',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 21, 0, 50, 32, tzinfo=datetime.timezone.utc),
#   1671319655384862721,
#   '#India: The #flood condition in #Assam deteriorated marginally on Tuesday, with nearly 34,000 people reeling under the impact of the deluge across nine districts\n\nhttps://t.co/HInlCcD47I',
#   'eTravelAlerts',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 20, 21, 22, 56, tzinfo=datetime.timezone.utc),
#   1671267414229807104,
#   '@HeedShift @peakaustria @Race2Extinct @iconickevin @Sashkapapashka @PoeBrianL @snowwolf Due to EL Nino India, Indonesia, Australia suffer from drought.\nBut it creates heavy rain &amp; flood in Somalia,Uganda.\n\nEL Nino is not favourable for cultivation whereas LA Nina favours farming.\n\n(2/2)',
#   'McPhersonGhoul',
#   8,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 20, 18, 7, 53, tzinfo=datetime.timezone.utc),
#   1671218327518330880,
#   'America is attempting to flood India with US dollars in order to split Eurasia. India recognizes it as a neocolonial policy.',
#   'rustem_sharipov',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 20, 16, 33, 28, tzinfo=datetime.timezone.utc),
#   1671194567457091595,
#   "Today in a discussion, on various issues faced by people with disabilities during disasters, with the American journalist Jason Strother who's been in India again on a short trip to watch & cover the community-led mock drills for cyclone & flood management conducted by @osdmaodisha yesterday to evaluate the community’s ability to respond to disasters and enhance coordination between departments.\n\nJason has been touring the entire Southeast Asian countries for last several months for shooting his documentary on the preparedness and response mechanism put in place by the governments of those countries to face various kinds of disasters.\n\n@Nidhi @Vkpandianfancl1",
#   'JBiswal',
#   14,
#   1,
#   1],
#  [datetime.datetime(2023, 6, 20, 16, 31, 16, tzinfo=datetime.timezone.utc),
#   1671194012739596288,
#   'Abey goojeet tere dimaag mein gobar bhara hai kya? 70% of Bihar remains under flood for 5 months and was systematically destroyed by first British and then fret equalization. Bengal was most industrialised and literate state in India during British and literally had the head.',
#   'Subutai45891585',
#   11,
#   1,
#   3],
#  [datetime.datetime(2023, 6, 20, 16, 30, 22, tzinfo=datetime.timezone.utc),
#   1671193785458622464,
#   "⚡ News from North East: \n\nThe flood situation in Assam continues to remain severe, with around 31,000 people affected across 10 districts of the state, according to officials   \n  \nIndia's Meteorological Department has issued a 'red alert' and foresees 'very heavy' to 'extremely heavy' rainfall in various districts of Assam over the next five days.   \n  \nThe Regional Meteorological Centre (RMC) of IMD located in Guwahati has issued a 'red alert' for the coming 24 hours, followed by an 'orange alert' for the following two days and a 'yellow alert' for Thursday.",
#   'BhavikaKapoor5',
#   109,
#   56,
#   8],
#  [datetime.datetime(2023, 6, 20, 16, 0, 3, tzinfo=datetime.timezone.utc),
#   1671186156262752259,
#   '#India, being a #peninsular country and surrounded by the #ArabianSea, #IndianOcean and the Bay of #Bengal is quite prone to floods.\n\nHere is a map showing Top Ten #Flood Prone Areas In India.\nhttps://t.co/VXOqTruyC6\n\n#MyIndia #Maps #MapsOfIndia',
#   'MapsofIndia',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 6, 20, 14, 44, 13, tzinfo=datetime.timezone.utc),
#   1671167072716595205,
#   "Watch: On News Reel\n\n* Indian #coughsyrups under scrutiny\n* #ElonMusk to call on #PMModi\n* Govt to probe #heatwave deaths\n* Will #Google 'Make in India?'\n* Relief for Indian #truck drivers\n* #Assam Floods: Over 30,000 affected\n\n@ArchanaaSolanki https://t.co/5X98LJkAcm",
#   'CNBCTV18News',
#   9,
#   3,
#   0],
# ...
#   'sagorika_s',
#   166,
#   44,
#   4],
#  [datetime.datetime(2023, 5, 10, 18, 0, 17, tzinfo=datetime.timezone.utc),
#   1656358513361186816,
#   '#OTD 250 years ago, the Tea Act became law in Great Britain and its colonies. Cheap British East India Company tea was to flood the 13 Colonies, saving it from insolvency, and enforce the supremacy of Parliament. The resulting backlash led to the Boston Tea Party. #RevWar250 https://t.co/rWTYaHNQ10',
#   'AmRevInstitute',
#   5,
#   4,
#   0],
#  [datetime.datetime(2023, 5, 10, 14, 28, 52, tzinfo=datetime.timezone.utc),
#   1656305306232836099,
#   '@AshwiniUpadhyay Demonetisations in India 🇮🇳, their Indian fake note industry was destroyed due to these . Second massive flood last year ( their food production was hampered) , 3rd too much depend on chines products ( their small scale industry destroyed), very less export &amp; Great Imran Khan 😜',
#   'sarveshkumar20',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 10, 14, 14, 15, tzinfo=datetime.timezone.utc),
#   1656301629522710529,
#   'Pakistan on the verge of civil war \n\n-PM &amp; Army General not in Pakistan \n-Army will be engaged internally \n-Complete Anarchy \n-High Inflation  \n-No Forex \n-Food scarcity\n-Recently occurred floods \n\nPerfect opportunity for India to take back POK??',
#   '_worldpolitics_',
#   7,
#   5,
#   1],
#  [datetime.datetime(2023, 5, 10, 13, 53, 34, tzinfo=datetime.timezone.utc),
#   1656296423279800326,
#   'this temple survived this flood.\nThe Kedarnath temple is built in the form of "North-South". While almost all the temples in India are "East-West". According to experts, if the temple was "east-west" it would have been destroyed long ago.',
#   'vijaybhoyer9',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 5, 10, 13, 53, 20, tzinfo=datetime.timezone.utc),
#   1656296362949087235,
#   'According to the Archaeological Society of India, 99% of the temple is completely intact in the audit of the entire structure of the temple even after the flood. "IIT Madras" to study the extent of damage to the structure during the 2013 flood and its current condition conducted',
#   'vijaybhoyer9',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 5, 10, 12, 51, 43, tzinfo=datetime.timezone.utc),
#   1656280860084289536,
#   '@_Me_Farhan_ @_FaridKhan The country is in grave trouble- food problems, flood issues, political unrest, security issues 😭😭😭😭- and still laughing at India.  🤔',
#   'RSu27738855',
#   3,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 10, 12, 48, 2, tzinfo=datetime.timezone.utc),
#   1656279931045793792,
#   '@nishant_kj I have cycled a large part of my youth out of necessity in India in 40+ centigrade heat and knee level floods. This cycle lane idea is a vanity project at this point in India cities, investments need to continue in large mass transport systems instead',
#   'svvisesh',
#   2,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 10, 12, 43, 10, tzinfo=datetime.timezone.utc),
#   1656278708359946240,
#   '@llewellynsteven @ed_hawkins We are not.\nOf the fifty most deadly floods ever recorded, only one, in India in 2013. occurred in the last fifty years.\nWe will experience more rainfall as the climate warms, but flood mitigation schemes have improved.\nWe will adapt, as we always have.',
#   'EJSDonald',
#   2,
#   0,
#   1],
#  [datetime.datetime(2023, 5, 10, 12, 21, 15, tzinfo=datetime.timezone.utc),
#   1656273191424393216,
#   'Like many streams and canals in urban environment in India, this stream also didnt have any buffer in case of severe floods and jailed with concrete walls and no room for it to breathe. For most of the year, these streams carry sewage water. https://t.co/h5x3LST5Vm',
#   'rajbhagatt',
#   54,
#   10,
#   1],
#  [datetime.datetime(2023, 5, 10, 9, 7, 48, tzinfo=datetime.timezone.utc),
#   1656224506506252293,
#   '@MattooShashank First interconnect all the river flowing in Northern region of india &amp; the with the middle &amp; south Indian rivers to bring prosperity here ( It will save enormous amount of water going waste daily &amp; particularly in rainy season - floods etc ) .',
#   'yashpalbhasin',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 10, 8, 21, 58, tzinfo=datetime.timezone.utc),
#   1656212972216385537,
#   '@InfiDale3476 Hey What is Noah called in Hebrew, I guess its Nuh. There is a similar story in Hinduism Of Manuh &amp; Matsya Incarnate of Vishnu.\nIntrestingly Nuh &amp; Manu are similar. After the flood This Manu Camped at Manali In Himachal Pradesh India.\nthe Hindi word Manus मनुष्य is derived from.',
#   'Vira_Ayush',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 10, 7, 33, 52, tzinfo=datetime.timezone.utc),
#   1656200870118268929,
#   '@Harisk60 Who fought against india in wars for our independence? Who did harsh duties in remote areas when we slept peacefully? Who helped and saved people from flood disaster?',
#   'abeeehaha',
#   1,
#   0,
#   2],
#  [datetime.datetime(2023, 5, 10, 6, 24, 27, tzinfo=datetime.timezone.utc),
#   1656183400661676032,
#   'India used to have such secondary channels and water reservoirs to absorb floods around cities. Xuanzang mentions temples in Varanasi “encircled by clear streams of water”. This channeling of the Ganges enabled dense urban quarters, like in Varanasi.\n\nhttps://t.co/31dyV7VDw2 https://t.co/NeUyaR9Vx5',
#   'vakibs',
#   6,
#   3,
#   2],
#  [datetime.datetime(2023, 5, 10, 6, 10, 17, tzinfo=datetime.timezone.utc),
#   1656179834366705664,
#   'Yes, Indian monsoons and snowmelt are violent and can discharge enormous amounts of water and flotsam. However, it is all a question of appropriate hydraulic engineering and sufficient buffer space for absorbing the flood. We don’t have such secondary river channels in India.',
#   'vakibs',
#   5,
#   3,
#   1],
#  [datetime.datetime(2023, 5, 10, 4, 59, 58, tzinfo=datetime.timezone.utc),
#   1656162139063865345,
#   'We have this, and in the other hand CN is going to flood the world with the car exports just as they did withe cell phones. So how is manufacturing moving out?\nHalf of the goods sold in India is now Made in… China !',
#   'Opu61659893',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 10, 4, 34, 16, tzinfo=datetime.timezone.utc),
#   1656155670805360642,
#   '@IAMCouncil Meitis r indigenous people of the oldest indigenous faith in the world! To accuse them of atrocity against Christians is despicable! American missionaries create anti-nationalists n India! Plus flood of undocumented Christians is problem! You are no friend of either people!',
#   'sudhaj12',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 10, 3, 49, 57, tzinfo=datetime.timezone.utc),
#   1656144519681789955,
#   '🇰🇪: Truck Driver Rescued after 6 Hours in Croc-infested Waters\n\nA routine crossing turned into a daring helicopter rescue from a raging 🐊 -infested river, after a truck was swept off the causeway by a sudden flash flood. https://t.co/0iMuubBvDC',
#   'RT_India_news',
#   5,
#   1,
#   2],
#  [datetime.datetime(2023, 5, 10, 1, 53, 51, tzinfo=datetime.timezone.utc),
#   1656115302604886016,
#   'India might benifit from taking lessons here. @sushantsareen @kushal_mehra pod talks about a scenario exactly like this one albeit with pakistan . The question is are we ready? Hope people in places take things seriously and prepare few ways to counter flood of people at border.',
#   'thatdhiraj',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 22, 26, 1, tzinfo=datetime.timezone.utc),
#   1656062995888209920,
#   "After election and before election there were NO SHOW of our lovely PM. There were floods, corona oxygen cylinder crisis. Road Show was very good. But NO SHOW is painful. NO PRIME MINISTER in India wouldn't have done such a ROAD SHOW in history. Modi did it in fear of Congress",
#   'super_hunter19',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 5, 9, 21, 56, 42, tzinfo=datetime.timezone.utc),
#   1656055620863410179,
#   "@fischerfischy @kevpluck another head in the sand screaming don't look don't look, Africa India, Pakistan, the Americas, Europe, Australia, if it didn't flood, burn, or have record crop losses in the last ten years it's in the denier's fantasy world https://t.co/tF4In0ePLg",
#   'scottpw7',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 19, 3, tzinfo=datetime.timezone.utc),
#   1656011906178506755,
#   '@alhaqmediaorg @AqssssSelin @TalibanUrdu years ago we talked about possible azab on pakistan in form of earthquakes floods or worse of all that is infighting,civil war and than possibly attack of enemy (india maybe?)...in group we had..you may remember that?my stance is same as then.And Allah knows best',
#   'muslim7003',
#   1,
#   0,
#   2],
#  [datetime.datetime(2023, 5, 9, 18, 41, 18, tzinfo=datetime.timezone.utc),
#   1656006444704059393,
#   'Floods on the road, wrestlers on the road, justice on the road. India is progressing but in a different direction.',
#   'prasunjain',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 17, 27, 59, tzinfo=datetime.timezone.utc),
#   1655987994531168258,
#   '@russeurope @stefan_demetz Yes. Many small drops make a flood.\nJust yesterday I read the construction sector needs as many as 5 million workers. \nTo my knowledge Russia still miss 2 million migrant workers compare to maximum few years ago.\nThey also are in the process of open for SCO workers from India aso',
#   'Lektor_KBN',
#   2,
#   0,
#   1],
#  [datetime.datetime(2023, 5, 9, 17, 0, 38, tzinfo=datetime.timezone.utc),
#   1655981110587985920,
#   '@RCTrader12 @trader1sz then you read wrong history mate and you have to correct it .. india helped pakistan in flood , indian helped ukrain and many more .. india is the country who want peace and help their enemy in thier bad condition .. you living in russia and and you think this about india itsbad',
#   'xbt_anonymous',
#   0,
#   0,
#   1],
#  [datetime.datetime(2023, 5, 9, 14, 30, 37, tzinfo=datetime.timezone.utc),
#   1655943358949507072,
#   '@TheRudra1008 @washingtonpost @zoo_bear Until India takes some strict action against these Rona Ayyub kinds, we would be having a flood of them.\n\nOur court let go of her fraud that crore of rupees is not that big amount, but a person working in any firm can be jailed in section 420 for even lakhs.\nDouble standards...',
#   'SmitaGarg8',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 14, 9, 24, tzinfo=datetime.timezone.utc),
#   1655938019835383816,
#   'Congress did nothing for infra for 70 years.  Thanks. Vajpayee ji and Modiji more so for great infra being build in India.  Huge intensity rains every city in the world floods.  Singapore orchid road too flooded. So don’t make a big fuss.',
#   'Finmech1',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 12, 40, 55, tzinfo=datetime.timezone.utc),
#   1655915752770404354,
#   '@MoD_India @MIB_India @NorthernComd_IA @NIA_India \nHIT them HARD in their CAMPS \nUse Drones &amp; Satellite imagery with \nDo &amp; Die personnel\nUse HELICOPTERs to Flood them with FAKE PKR currency as they did recently in BHARAT\nBomb north Kashmir AIRSTIPS used by China',
#   'AAPVora',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 12, 9, 4, tzinfo=datetime.timezone.utc),
#   1655907737786540033,
#   'Our heartfelt gratitude to HSBC Global Service Centre, India\xa0 for enabling Nirmaan Organization to work for the #Rehabilitation of #Flood-#affected families in #Bhadrachalam. https://t.co/3SI1uR4iLY',
#   'kesaniuma',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 10, 34, 6, tzinfo=datetime.timezone.utc),
#   1655883838462074880,
#   '@elonmusk @stillgray Why only for White nations though? China and India aren\'t being pressured to flood their nations with foreigners in order to "succeed". Why should entire nations &amp; cultures be sacrificed so that Corporations &amp; Billionaires can have cheap labor while destroying the local economy?',
#   'GreatGoban',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 9, 45, tzinfo=datetime.timezone.utc),
#   1655871480813572098,
#   '#ClimateCrisis | Globally, there has been a 134% increase in #climate-fuelled, flood-related disasters between 2000 &amp; 2023, according to the @UNDP. And #Rwanda, which is naturally vulnerable to #floods, has become a flashpoint.\n\nhttps://t.co/G4QSHjRMRl https://t.co/j01D3RyMUb',
#   'frontline_india',
#   3,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 8, 47, 16, tzinfo=datetime.timezone.utc),
#   1655856951127859200,
#   '@AbhishBanerj @zeedee93 Its so sad some indian liberals were even saying bangladesh will overtake india ,what a lie .They will end in arms of china like pak .So many hindu killings and they flood India .Do clothes for west \nFor a pittance ,sorry for india 2 failed states sorround you.But you will \nWin.',
#   'BS207BS',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 8, 34, 28, tzinfo=datetime.timezone.utc),
#   1655853732695887872,
#   'Our heartfelt gratitude to @hsbc_in Global Service Centre, India for enabling #nirmaan Organization to work for the #Rehabilitation of #Flood-#affected families in #Bhadrachalam. https://t.co/H2H6yO4Zzy',
#   'Nirmaan_Org',
#   2,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 8, 32, 4, tzinfo=datetime.timezone.utc),
#   1655853128443654146,
#   '@JayantBhandari5 It is incomprehensible to our Middle Class - who uniquely expanded what was most American - to grasp this same class in India would be the one to utterly displace &amp; destroy them.\n\nOur Border will flood society with Hellholes, but Indians shall rule over our new Land of Hellholes.',
#   'Ethelleas',
#   2,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 6, 51, 13, tzinfo=datetime.timezone.utc),
#   1655827748248764417,
#   "and after today's gaza strip strikes you will see a lot of Indians showing solidarity with Israel in their posts ..a flood of posts will originate from India  praising Israeli action. and Arabs will keep giving the same indoos jobs in Gulf",
#   'muslim7003',
#   2,
#   2,
#   2],
#  [datetime.datetime(2023, 5, 9, 6, 42, 7, tzinfo=datetime.timezone.utc),
#   1655825458246606849,
#   '@yuccaldo @ClimateBen Yes.\n\nDeadly climatic events are already on the rise (heat waves in india, south-east asia, floods), species extinctions have been increasing for years, the poles ice caps are melting, we are losing glaciers, water supply is getting very complicated in many places...',
#   'bdunogier',
#   1,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 9, 4, 59, 38, tzinfo=datetime.timezone.utc),
#   1655799666217218048,
#   "#NewZealand's largest city of #Auckland on Tuesday declared a local state of emergency due to #floods and torrential rainfall.\n\nTraffic was at a standstill in Auckland, as the city entered its third state of emergency due to severe weather this year. https://t.co/MTLdLiBJ41",
#   'ians_india',
#   1,
#   0,
#   1],
#  [datetime.datetime(2023, 5, 9, 2, 18, 39, tzinfo=datetime.timezone.utc),
#   1655759152277504002,
#   '#insurance\nAgriculture in India is highly susceptible to risks like droughts and floods. It is necessary to protect the farmers from natural calamities.. \nBLUEROSE STORE\nhttps://t.co/3f0gX2E2Kx\nAMAZON\nhttps://t.co/8pDjBcOVgO\nFLIPKART\nhttps://t.co/tRtRQ3KTbu https://t.co/N59H78bj2P',
#   'RanaJagendra',
#   0,
#   0,
#   0],
#  [datetime.datetime(2023, 5, 8, 20, 43, 39, tzinfo=datetime.timezone.utc),
#   1655674848088293376,
#   '#2018Movie is one of the best visual effect movie from Kerala(even India). Technically brilliant in all depts &amp; on the helm, direction from #JudeAnthanyJoseph. This is a cinematic experience of the Kerala floods 2018 and all actors played it to perfection.\nMust watch in theatres.',
#   'VijayGanapathyG',
#   103,
#   20,
#   1],
#  [datetime.datetime(2023, 5, 8, 17, 3, 55, tzinfo=datetime.timezone.utc),
#   1655619552385073152,
#   '@bhairav_hara The careless approach of the previous governments had allowed a flood of illegal immigrants in India. To identify and flush them out it is necessary to prepare a record of the legal and illegal residents of India. NRC is the only way to make the identification.',
#   'ManishS25440423',
#   0,
#   1,
#   0],
#  ...]

# %%
# tweet_df = pd.DataFrame(tweet_data, columns=['date', 'id', 'content', 'username', 'like', 'retweet'])
tweet_flood_df = pd.DataFrame(tweet_data, columns=['date', 'id','content', 'username','like', 'retweet','reply_count'])

# %%
tweet_flood_df['date'] = pd.to_datetime(tweet_flood_df['date']).dt.date

# %%
tweet_flood_df.to_excel("twitter.xlsx",index= False)

# %%
df= pd.read_excel("twitter.xlsx")
df.head()
# Out:
#         date                   id  \
# 0 2023-06-23  1672155919591907072
# 1 2023-06-23  1672153301687706112
# 2 2023-06-23  1672147284879113984
# 3 2023-06-23  1672135940477731072
# 4 2023-06-23  1672130361378189056
#
#                                              content         username  like  \
# 0  #AssamFloods update: There is no respite from ...    airnewsalerts     1
# 1  At least 496 thousand people were in the flood...      rusashanews     0
# 2  @centerofright @NagpurKaRajini Jai Agniveers a...  niranjan_nalkur     0
# 3  FLOOD SITUATION IN ASSAM WORSENS.0\n #Titanic ...  TheBharatIndia1     1
# 4  #Assam State Disaster Management Authority (AS...       ians_india     1
#
#    retweet  reply_count
# 0        0            0
# 1        0            1
# 2        0            0
# 3        0            0
# 4        0            0
