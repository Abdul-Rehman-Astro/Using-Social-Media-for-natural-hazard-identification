# %%
#reference : https://www.youtube.com/watch?v=PUMMCLrVn8A&ab_channel=RobMulla

# %%
pip install git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Collecting git+https://github.com/JustAnotherArchivist/snscrape.git
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-zrerj2c1
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-zrerj2c1
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 614d4c2029a62d348ca56598f87c425966aaec66
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests[socks] in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (2.28.1)
# Requirement already satisfied: lxml in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (4.11.1)
# Requirement already satisfied: filelock in /home/krishna/anaconda3/lib/python3.9/site-packages (from snscrape==0.7.0.20230622) (3.6.0)
# Requirement already satisfied: soupsieve>1.2 in /home/krishna/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->snscrape==0.7.0.20230622) (2.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (2022.9.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/krishna/anaconda3/lib/python3.9/site-packages (from requests[socks]->snscrape==0.7.0.20230622) (1.7.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import snscrape.modules.twitter as sntwitter

# %%
scraper = sntwitter.TwitterSearchScraper('flood  "flood" (flood OR or OR cloudburst) lang:en')
scraper = flood  "Flood " (flood OR cloudburst OR Monsoon ) (#flood) min_replies:5 min_faves:100 min_retweets:10 lang:en until:2022-09-30 since:2022-06-01
scraper = sntwitter.TwitterSearchScraper('flood  "Flood " (flood OR cloudburst OR Monsoon ) (#flood) min_replies:5 min_faves:100 min_retweets:10 lang:en until:2022-09-30 since:2022-06-01')

flood  "flood" (flood OR Monsoon) -Pakisthan -Bangladesh -California(#Flood) min_replies:2 min_faves:50 min_retweets:5 lang:en since:2022-06-01

scraper = sntwitter.TwitterSearchScraper('flood  "flood" (flood OR Monsoon) -Pakisthan -Bangladesh -California(#Flood) min_replies:2 min_faves:50 min_retweets:5 lang:en since:2022-06-01')
scraper = sntwitter.TwitterSearchScraper('flood India lang:en')

# %%
scraper = sntwitter.TwitterSearchScraper('flood  "flood" (flood OR Monsoon) -Pakisthan -Bangladesh -California(#Flood) min_replies:2 min_faves:50 min_retweets:5 lang:en since:2022-06-01')

# %%
type(scraper)
# Out:
# snscrape.modules.twitter.TwitterSearchScraper

# %%
tweet_data_with_user_location=[]
for i,tweet in enumerate(scraper.get_items()): 
    tweet_list = [
        tweet.date,
        tweet.id,
        tweet.content,
        tweet.user.username,
        tweet.likeCount,
        tweet.retweetCount,
        tweet.user.location  # Add the user location to the tweet_list
    ]
    tweet_data_with_user_location.append(tweet_list)
    if i==10000:
        break
# Out:
# /tmp/ipykernel_31578/3737331484.py:6: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweet.content,
# Could not translate t.co card URL on tweet 1672277216019750913
# Could not translate t.co card URL on tweet 1671438195093823492
# Unavailable user in card on tweet 1669655967192219648
# User 1667612219654262789 not found in user refs in card on tweet 1669655967192219648
# Could not translate t.co card URL on tweet 1667300165529796608
# Unavailable user in card on tweet 1660414147329413120
# User 1411470135496298499 not found in user refs in card on tweet 1660414147329413120
# Could not translate t.co card URL on tweet 1659120942273146880
# Could not translate t.co card URL on tweet 1658040084963426306
# Could not translate t.co card URL on tweet 1656721761855995912
# Could not translate t.co card URL on tweet 1654950192591040512
# Could not translate t.co card URL on tweet 1654536089057603592
# Could not translate t.co card URL on tweet 1651279978846208028
# Stopping after 20 empty pages

# %%
tweet_data_with_user_location
# Out:
# [[datetime.datetime(2023, 6, 28, 4, 54, 43, tzinfo=datetime.timezone.utc),
#   1673917823100522498,
#   "One main cause of these floods is infrastructure- mindless unplanned infrastructure of the pervert criminal modi. European Geosciences Union's Journal says, since 2014, 20% of landslides - the maximum in the world - have been happening in India. In 9 years of his rule, the skunk",
#   'Ashwini96988554',
#   0,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 28, 4, 51, 55, tzinfo=datetime.timezone.utc),
#   1673917116733349889,
#   '@TimothyGouldso1 @JustinTrudeau world wide we have this problem, fires, floods, storms..\ncertain countries give a shit about climate , they give a shit abut fires ..as long as it fills their pockets. India is worse .. USA is worse .. very close to Canada , right..',
#   'londonwriters',
#   0,
#   0,
#   'Vancouver / Toronto / London, Montreal , Roma'],
#  [datetime.datetime(2023, 6, 28, 4, 51, 43, tzinfo=datetime.timezone.utc),
#   1673917069488979968,
#   "Did y'all know that since 2014, India as become the world's second worst afflicted country prone to flash floods and landslides, after Bangladesh. Check the International Disaster Database- since 2014, an average of 1,500 Indians have died due to floods- one main cause is infrast",
#   'Ashwini96988554',
#   1,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 28, 4, 30, 12, tzinfo=datetime.timezone.utc),
#   1673911653652627456,
#   'Assam Braces for Eid Amidst Devastating Floods and Rising Vegetable Prices #Assam #EidAlAdha \nRead Here 👇\nhttps://t.co/M57QO2vVWH https://t.co/c0y4oSolol',
#   'newsnortheastin',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 28, 4, 30, tzinfo=datetime.timezone.utc),
#   1673911602402451456,
#   'Heavy rains hit the city of #Ahmedabad, #India, causing flooding for at least the second time this month. \n\nDeadly rains and floods in the Indian state of #Gujarat have become more common in recent years, with over 225 people dying after heavy rains hit the area in 2017. https://t.co/clcuWgykFA',
#   'cgtnamerica',
#   3,
#   1,
#   'Washington, DC'],
#  [datetime.datetime(2023, 6, 28, 4, 23, 4, tzinfo=datetime.timezone.utc),
#   1673909859346182145,
#   "#BangkokPost: Flood victims in India's northeastern flood-ravaged Assam state have been forced to rebuild their lives from rubble after losing their homes and livelihood to the water. They gathered at a relief shelter on Tuesday (June 27) with the scarce amount of belongings that they were able to hang on to. - REUTERS #video\nhttps://t.co/iWE1iiAMjy",
#   'BangkokPostNews',
#   0,
#   1,
#   'Thailand'],
#  [datetime.datetime(2023, 6, 28, 4, 13, 52, tzinfo=datetime.timezone.utc),
#   1673907543704494080,
#   'Floods Hit Barpeta District, Assam: Over 67,000 Affected and Counting #Barpeta #Assam\nClick here 👇\nhttps://t.co/UNcNkuUhU3 https://t.co/oSHp3OAxDA',
#   'newsnortheastin',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 28, 4, 5, 48, tzinfo=datetime.timezone.utc),
#   1673905511832629249,
#   'Things To Witness Once Before You Die In,India \n\n1. Non Polluted "Delhi" \n2. Floods Of "Rajasthan"\n3. Achee Din Of "BJP🌺"',
#   'RohitCh21443690',
#   0,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 28, 4, 5, 7, tzinfo=datetime.timezone.utc),
#   1673905340398862336,
#   'VIDEO | Several villages in Sonitpur district of Assam continue to reel under the impact of floods. https://t.co/k2bE5Dz10Y',
#   'PTI_News',
#   21,
#   4,
#   'New Delhi, India'],
#  [datetime.datetime(2023, 6, 28, 4, 4, 5, tzinfo=datetime.timezone.utc),
#   1673905081614467072,
#   'Major Landslide in India\n1) The Malpa landslide was one of the worst landslides in India. On 18 August 1998, a massive landslide wiped away the entire village of Malpa in the Pithoragarh district of Uttarakhand.\n\n2) The Durmi Lake dam-burst was a flood in the Garhwal Region of India in 1894 caused by a landslide-induced temporary lake.\n\n3) On 30 July 2014, a landslide occurred in the village of Malin in the Pune district in Maharashtra. It was believed to have been caused by a burst of heavy rainfall.\n\n4) The 2000 Mumbai landslide was a landslide that occurred in Ghatkopar. The landslide was caused by land erosion, following heavy rains and subsequent flooding that coincided with a high tide in the Arabian Sea.\n\n5) 2013 Uttarakhand floods and landslides\n\nThese examples can be mentioned in Landslide questions. You can also draw a map of India and show the examples above on the map.\n\n#UPSC #UPSCEXAM #UPSC2023',
#   'gjsontake',
#   11,
#   2,
#   'Pune, India'],
#  [datetime.datetime(2023, 6, 28, 3, 2, 51, tzinfo=datetime.timezone.utc),
#   1673889672630599683,
#   "'#Flood the #Economy': #China's #Stimulus #Errors hurt #Stocks as #Funds #Flee to #India, #Japan, us #Markets, #Strategist says https://t.co/V62qqSkckn source: #scmp",
#   'latticenews',
#   0,
#   0,
#   'United Kingdom'],
#  [datetime.datetime(2023, 6, 28, 2, 58, 6, tzinfo=datetime.timezone.utc),
#   1673888475287011328,
#   "Narendra Modi asks JP Nadda what's going on in India. Boasts about street vendors using digital payments but on junkets, he can't perform his PM role.\n\nManipur burns, Muslims lynched, tomatoes at ₹100/Kg, floods ravage, heat waves roast. His next stop? BJP Madhya Pradesh event. https://t.co/I4OLMsqAjE",
#   'santhoshd',
#   1,
#   0,
#   'Terra Unfirma'],
#  [datetime.datetime(2023, 6, 28, 2, 34, 27, tzinfo=datetime.timezone.utc),
#   1673882523649073153,
#   'Flash Floods and Landslides In Northern India\n\n#GS3  #Environment  #DisasterManagement\n\nRead here,\nhttps://t.co/eNivGaJNBk\n\nFor More Details\nVisit: https://t.co/dO80dvn2I5\nEmail: Believersiasacademy@gmail.com/ info@believersias.com\nCall@+91 9611321616/+91 9611451616 https://t.co/f3IiXTIq0w',
#   'BelieversIas',
#   0,
#   0,
#   'BTM Layout, Bengaluru South'],
#  [datetime.datetime(2023, 6, 28, 2, 1, 40, tzinfo=datetime.timezone.utc),
#   1673874273021091840,
#   "India floods: 'I have to start again from zero' https://t.co/JhEWAiGxOx",
#   'amitsharmalie',
#   0,
#   0,
#   'Hempstead, NY'],
#  [datetime.datetime(2023, 6, 28, 1, 22, 34, tzinfo=datetime.timezone.utc),
#   1673864432294805506,
#   'Thank u @SabrinaSiddiqui for standing up last week asking the hard question to an undemocratic leader who has unleashed flood of hate across nation of billion people &amp; when the journalist within #india have shown no morality in selling the nation for petty gains. #SabrinaSiddiqui',
#   'zuberjafri',
#   0,
#   0,
#   'Pennsylvania, USA'],
#  [datetime.datetime(2023, 6, 28, 0, 57, 1, tzinfo=datetime.timezone.utc),
#   1673858003206848514,
#   "@1MRNES In the last few years my parish has welcomed new immigrant families from Eritrea, Ukraine, Belarus, Russia, &amp; India. Alongside of a flood of new converts from all sorts of religious backgrounds. They're all wonderful &amp; it's an incredible moment in time to be part of.",
#   'PeterJTosh1',
#   2,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 28, 0, 33, 56, tzinfo=datetime.timezone.utc),
#   1673852195886776320,
#   'India Floods.',
#   'SebastianKoh8',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 23, 52, 47, tzinfo=datetime.timezone.utc),
#   1673841836723703808,
#   "Someone posing as a assistant for Mr Bill Pulte. Contacts you and says you've won $10,000. It's a scam he will use this email.\nBillwilliampulte1@gmail.com\nAs a matter of fact flood this email \nWith messages.They forgot the time difference between here and India.  Red dot scammers https://t.co/JsisNworeT",
#   'murdaugh_drew',
#   2,
#   0,
#   'Los Angeles, CA'],
#  [datetime.datetime(2023, 6, 27, 23, 51, 33, tzinfo=datetime.timezone.utc),
#   1673841526554914818,
#   'Must those, the twain beside our vital flood, \n#项城市 #错那市 #登封市 #福清市 #溧阳市 https://t.co/t1VafOeazo',
#   'IndiaMarsh38786',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 23, 51, 10, tzinfo=datetime.timezone.utc),
#   1673841431008669696,
#   "@tehseenp @chittukuruvi4 Nope that's not the benchmark when WSJ or other media outlets try to create fake narrative then then they should be shown their places . I saw flood of tweet when BBC india was raided calling it witch hunt where those outlets were when BBC acknowledge the 40CR underreporting ?",
#   'parasmerc',
#   1,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 23, 21, 55, tzinfo=datetime.timezone.utc),
#   1673834071007297538,
#   '@PurePoll New Delhi, Hong  Kong, Cairo, Pretoria, etc. was built by the British, so by this logic, millions of native Brits can flood into Egypt, South Africa, India, China, etc.',
#   'ThatGuy3196',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 22, 41, 33, tzinfo=datetime.timezone.utc),
#   1673823911329533954,
#   "India floods: ‘I have to start again from zero’ #IndiaNews #WorldNews #NationalNews [Video] Flood victims in India's northeastern flood-ravaged Assam state have been forced to rebuild their lives from rubble after losing their homes and livelihood to the… https://t.co/Fb9lYVSTJW",
#   'GabbyWEUNV',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 22, 36, 21, tzinfo=datetime.timezone.utc),
#   1673822602194825216,
#   "@ARanganathan72 @BluOneInk There's no one more articulate and bang on facts that you Doc. I am not in India for a decade now, but closely follow the politics and the current affairs. You always shed a flood light on the truth no matter who gets exposed or deserves an applause. 🙏🏼🙏🏼",
#   'A10ARK',
#   0,
#   0,
#   'Timbaktu'],
#  [datetime.datetime(2023, 6, 27, 21, 50, tzinfo=datetime.timezone.utc),
#   1673810938112401408,
#   "Flood victims in India's northeastern flood-ravaged Assam state have been forced to rebuild their lives from rubble after losing their homes and livelihood to the water https://t.co/kFih4qkU4G",
#   'ReutersAsia',
#   3,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 21, 28, 54, tzinfo=datetime.timezone.utc),
#   1673805629046112257,
#   '@ADHDdesigner Growing up, I did the chore of filling up a matki (earthen pot - traditional water storage in India) through a filtered pipe which slowly trickled. So you had to sit &amp; wait...worst kind of job for someone with ADHD. Dozens of floods. Still have nightmares of some tap I left on.',
#   'apaxon',
#   1,
#   0,
#   'Boston'],
#  [datetime.datetime(2023, 6, 27, 21, 20, tzinfo=datetime.timezone.utc),
#   1673803388960616450,
#   'A woman in India was saved from almost certain death at the hands of the Ghaggar River, having parked her car on its banks despite warnings of torrential floods. https://t.co/Jou35IcD4F',
#   'RT_com',
#   148,
#   29,
#   ''],
#  [datetime.datetime(2023, 6, 27, 20, 22, 54, tzinfo=datetime.timezone.utc),
#   1673789018922962944,
#   "Thank God for Hindu India, every year we could have just let the gates open and flood lower lying delta area of Bangla. But we ensure no Muslim dies due to Hindu river overflowing. It's not sarcasm. It's truth.",
#   'ShivoBhairava',
#   0,
#   0,
#   'saptsindhu'],
#  [datetime.datetime(2023, 6, 27, 20, 15, tzinfo=datetime.timezone.utc),
#   1673787030596202500,
#   "People in India's northeastern state of Assam have been forced to rebuild their lives from rubble after their state was ravaged by floods. Many have gathered at a relief shelter with the scarce amount of belongings that they were able to hang on to https://t.co/pJOdnshqcr",
#   'Reuters',
#   47,
#   13,
#   'Around the world'],
#  [datetime.datetime(2023, 6, 27, 19, 20, 16, tzinfo=datetime.timezone.utc),
#   1673773256870969344,
#   '@flying_dusk @michaelxpettis Why is it time to change it?\n\nThe WTO was a tool for the West to flood third world countries with foreign products, and today, when new competitors like India, China, and Asia have emerged, they want to change the game.',
#   'SaeedFX1',
#   0,
#   0,
#   'Between EURUSD'],
#  [datetime.datetime(2023, 6, 27, 18, 3, tzinfo=datetime.timezone.utc),
#   1673753812073345032,
#   "A 61-year-old woman found herself trapped in her car when the #Ghaggar River in India began to #flood its banks. The woman, who ignored the authorities' warnings of torrential conditions, became stuck inside her vehicle as it was swept away by the rising #river. https://t.co/wXqH62XWZE",
#   'RT_Doc',
#   1,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 27, 18, 0, 2, tzinfo=datetime.timezone.utc),
#   1673753066393272320,
#   "Five people are killed and over 155,000 affected in India's northeastern state of Assam as flash floods hit region, forcing people to flee their homes https://t.co/3WCL51RcLU",
#   'TRTWorldNow',
#   6,
#   0,
#   'Istanbul, Türkiye'],
#  [datetime.datetime(2023, 6, 27, 17, 34, 16, tzinfo=datetime.timezone.utc),
#   1673746580338540544,
#   "India floods: 'I have to start again from zero' https://t.co/XvZZZ6rC21 via @YouTube",
#   'Beverlylovesboi',
#   1,
#   0,
#   'Las Vegas, Nevada, USA'],
#  [datetime.datetime(2023, 6, 27, 17, 28, 6, tzinfo=datetime.timezone.utc),
#   1673745028559294464,
#   "India floods: 'I have to start again from zero' #AndyVermautLovesReutersPressAgency https://t.co/dfvH868io1 https://t.co/f5Mjsa1IBN",
#   'AndyVermaut',
#   0,
#   0,
#   'Diksmuide, België'],
#  [datetime.datetime(2023, 6, 27, 17, 28, 4, tzinfo=datetime.timezone.utc),
#   1673745023027023872,
#   "India floods: 'I have to start again from zero' #reuters https://t.co/5xyp4BtMP6",
#   'rogue_corq',
#   0,
#   0,
#   'Up in ur timeline'],
#  [datetime.datetime(2023, 6, 27, 17, 28, 4, tzinfo=datetime.timezone.utc),
#   1673745021445734400,
#   "India floods: 'I have to start again from zero' https://t.co/m1gf2sCRa2",
#   'mubasheer2022',
#   0,
#   0,
#   'Taif, Saudi Arabia'],
#  [datetime.datetime(2023, 6, 27, 17, 10, tzinfo=datetime.timezone.utc),
#   1673740473708560410,
#   "People in India's northeastern state of Assam have been forced to rebuild their lives from rubble after their state was ravaged by floods. Many have gathered at a relief shelter with the scarce amount of belongings that they were able to hang on to https://t.co/R3wHyhHYFw",
#   'ReutersAsia',
#   2,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 27, 16, 20, 33, tzinfo=datetime.timezone.utc),
#   1673728031985205248,
#   'Video: Car washed away in flash floods as heavy rains lash Haryana’s Panchkula, woman occupant saved | News - Times of India Videos\nvia The Times of India https://t.co/loBAcaqZa8',
#   'CNode_news',
#   0,
#   0,
#   'nr Cambridge, UK'],
#  [datetime.datetime(2023, 6, 27, 16, 15, tzinfo=datetime.timezone.utc),
#   1673726633423917056,
#   "Flood victims in India's northeastern flood-ravaged Assam state have been forced to rebuild their lives from rubble after losing their homes and livelihood to the water https://t.co/WeTb5QrmOi",
#   'Reuters',
#   39,
#   12,
#   'Around the world'],
#  [datetime.datetime(2023, 6, 27, 16, 4, 58, tzinfo=datetime.timezone.utc),
#   1673724108645826562,
#   'This should be everywhere in India to keep lower parts of the cities flood free.\nSimple low cost and effective way to keep infra safe and roads drivable. \n\n https://t.co/ztbPCseSPu',
#   'ZupiterMonk',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 15, 52, 41, tzinfo=datetime.timezone.utc),
#   1673721017619951620,
#   'Crowd-sourcing can offer data to forecast floods in city: IIT-Bombay study | Mumbai News - Times of India\nvia The Times of India https://t.co/iiMB4tLSqb',
#   'CNode_news',
#   0,
#   0,
#   'nr Cambridge, UK'],
#  [datetime.datetime(2023, 6, 27, 15, 41, 58, tzinfo=datetime.timezone.utc),
#   1673718319298297856,
#   '@DaleVince @KayBurley @SkyNews @JustStop_Oil Have you listened to or read any of Bjorn Lomborgs work? Any thoughts on why we encourage people to build on flood plains? How about using scarce resources in the best possible way, like replacing the bikes in India?',
#   'waynelico',
#   0,
#   0,
#   'England, United Kingdom'],
#  [datetime.datetime(2023, 6, 27, 14, 45, 57, tzinfo=datetime.timezone.utc),
#   1673704225430466560,
#   "I'm excited to share my latest research article on the July 2022 #floods in India's lower #GodavariRiver catchment. Witness the dual power of #earthobservation &amp; #googleearthengine! @CWCOfficial_GoI @ISRO @ndmaindia @NDRFHQ @UN_SDG #disasterplanning\nhttps://t.co/7ehLHnpD5t https://t.co/ANhKKmdEe8",
#   'Jayesh_rivers',
#   7,
#   2,
#   'Kolkata 🛫 New Delhi 🇮🇳'],
#  [datetime.datetime(2023, 6, 27, 14, 0, 30, tzinfo=datetime.timezone.utc),
#   1673692787311796224,
#   'Barpeta District: Relief Camps Provide Shelter and Support to Flood-Affected Individuals  #AssamFloods #Assam #Floods\nRead Here 👇\nhttps://t.co/eL348J7X8o https://t.co/WQNyeE3e07',
#   'newsnortheastin',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 14, 0, 7, tzinfo=datetime.timezone.utc),
#   1673692690188488705,
#   '#Assam | The people affected by floods in the Barpeta district are taking shelter in relief camps set up by the district administration as well as roads and embankments. In the Kayakuchi area, around 100 families have taken shelter at the Paka Betbari Development Block campus https://t.co/c8vU0j568b',
#   'NewsMobileIndia',
#   0,
#   1,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 13, 56, 1, tzinfo=datetime.timezone.utc),
#   1673691658020352002,
#   'Torrential rains and lightning claim lives across India as monsoon advances. Punjab and Himachal Pradesh hit hard, with landslides, floods, and road damage. Losses exceed $12.2 million in Punjab. Monsoon covers 80% of the country. Infrastructure woes persist.  #NaturalDisasters https://t.co/0GQzYwmunt',
#   'KIDataApp',
#   0,
#   1,
#   'San Francisco'],
#  [datetime.datetime(2023, 6, 27, 12, 55, 49, tzinfo=datetime.timezone.utc),
#   1673676506868981761,
#   'Indian States Reel Under Monsoon’s Deadly Flash Floods and Landslides \n#india #indianstates #uttrakhand #himachalpradesh #himachal #flashfloods #landslides #HeavyRainfall #HeavyRainfallAlert \nhttps://t.co/EVT7LIydiu',
#   'TodayOnGlobe',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 12, 50, 12, tzinfo=datetime.timezone.utc),
#   1673675094785241090,
#   'Extreme weather in Asia: Heat in Beijing and floods in India https://t.co/gUeupum9Kv https://t.co/wzwU9ieUt2',
#   'RLFFLLCWX',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 12, 50, 11, tzinfo=datetime.timezone.utc),
#   1673675091563933698,
#   'Extreme weather in Asia: Heat in Beijing and floods in India https://t.co/rdRiFR9dnd https://t.co/yjAFNJz6NT',
#   'RedLights4FF',
#   0,
#   0,
#   'Watertown, NY'],
#  [datetime.datetime(2023, 6, 27, 12, 35, 21, tzinfo=datetime.timezone.utc),
#   1673671358474072068,
#   '#AssamFlood situation in last 24 hours..\n.\n#flood #disaster #disasterpreparedness\n#DisasterResponse #disasterrecovery #awareness\n#flooddamage #stayinformed \n\n@diprassam @mygovassam @ndmaindia @mygovindia @PIB_Guwahati @PIB_India @CMOfficeAssam @JogenMohanAssam https://t.co/Y7TSknd5jF',
#   'sdma_assam',
#   3,
#   1,
#   'Guwahati, India'],
#  [datetime.datetime(2023, 6, 27, 12, 16, 41, tzinfo=datetime.timezone.utc),
#   1673666659385499649,
#   'Assam Floods: Significant Improvement Seen, Barpeta District Remains Affected  #Floods #Barpeta\n#Assam \nExplore here👇\nhttps://t.co/ZsM5Hiu5vB https://t.co/WuNga9fsxL',
#   'newsnortheastin',
#   1,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 27, 12, 14, 20, tzinfo=datetime.timezone.utc),
#   1673666067636404228,
#   'Hyderabad Floods: Rapid urbanisation, change in land use resulting in frequent flooding in Hyderabad | Hyderabad News - Times of India\nvia The Times of India https://t.co/0LAN2F5jn9',
#   'CNode_news',
#   0,
#   0,
#   'nr Cambridge, UK'],
#  [datetime.datetime(2023, 6, 27, 11, 50, 45, tzinfo=datetime.timezone.utc),
#   1673660133023395844,
#   '@monkwhosoldpen @Rohan_Bhargava_ @JhaSanjay Yes! The main agenda is to displace Muslim Population from their homelands and flood the west with them as conflict all over the world is business for them.\n\nAlso I was asking whether they have any data on the number of Muslims who left India and took refuge. \n\nSo far nothing',
#   'LauraaListen',
#   1,
#   0,
#   'In My Head'],
#  [datetime.datetime(2023, 6, 27, 11, 37, 51, tzinfo=datetime.timezone.utc),
#   1673656886263001092,
#   "Empower yourself to be a hero in times of crisis! Join RLSS (India) Lifesaver Community and equip yourself with essential skills to save lives during floods and other emergencies. Together, let's be prepared and make a difference. Visit https://t.co/JCcv7IYj7E https://t.co/iAaG6LFngc",
#   'RLSSIndia',
#   0,
#   0,
#   'Pune, India'],
#  [datetime.datetime(2023, 6, 27, 11, 36, 20, tzinfo=datetime.timezone.utc),
#   1673656503746588673,
#   'Request to @myogiadityanath , @BJP4India ,@INCIndia ,@RajGovOfficial ,@CMOMaharashtra Please make some policies &amp; conserve flood water &amp; make underground storage. India receives abundant rainfall, rain H2O could be used during drought  in Maharastra, M.P,\n Rajasthan, U.P etc.🇮🇳🙏',
#   'IndianBN2K40',
#   0,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 11, 35, tzinfo=datetime.timezone.utc),
#   1673656168747597824,
#   '#Flood | Watch your step during #floods. https://t.co/5J7gr1hvwb',
#   'ndmaindia',
#   2,
#   1,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 27, 11, 30, tzinfo=datetime.timezone.utc),
#   1673654911744233473,
#   'Heavy rains hit the city of #Ahmedabad, #India, causing flooding for at least the second time this month. \n\nDeadly rains and floods in the Indian state of #Gujarat have become more common in recent years, with over 225 people dying after heavy rains hit the area in 2017. https://t.co/vQxjnf3R6B',
#   'cgtnamerica',
#   4,
#   0,
#   'Washington, DC'],
#  [datetime.datetime(2023, 6, 27, 11, 19, 58, tzinfo=datetime.timezone.utc),
#   1673652387230408704,
#   "@narendramodi I am a Bangladeshi requesting Mr. Modi to make proper steps safe foods and chemicals so that the people become productive more to struggle to fulfill their needs in my country as my country is in the downstream of India pay a heavy toll in each year's flood and rainfall.",
#   'refin21',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 11, 6, tzinfo=datetime.timezone.utc),
#   1673648870394572803,
#   '#Floods | Remember to turn off power &amp; gas connections to ensure #safety during #Floods. https://t.co/5tEdpkzdGf',
#   'ndmaindia',
#   10,
#   2,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 27, 10, 53, 5, tzinfo=datetime.timezone.utc),
#   1673645621792899075,
#   'On Tuesday, flood-ravaged #Assam finally experienced some relief following a decrease in rainfall.\n\nThe deluge has claimed 5 lives and affected over 1.5 lakh people. Barpeta continues to bear the brunt of the devastation.\n\nRead: https://t.co/Dd0NIULkvh\n\n📸: IANS https://t.co/urgTyZJJbQ',
#   'weatherindia',
#   6,
#   1,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 10, 40, 30, tzinfo=datetime.timezone.utc),
#   1673642454774415360,
#   "In #UttarPradesh 's #Meerut district, a section of a #bridge connecting two towns over the #Ganga river collapsed due to the powerful water flow caused by #heavyrainfall\n#bridgecollapse #Floods https://t.co/ZfCcBzAaSP",
#   'IndiaObservers',
#   0,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 10, 40, tzinfo=datetime.timezone.utc),
#   1673642327175495681,
#   "#Floods | Don't use any damaged electrical goods during floods. https://t.co/DSsMyIPLir",
#   'ndmaindia',
#   6,
#   2,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 27, 10, 36, 52, tzinfo=datetime.timezone.utc),
#   1673641537945718784,
#   'Assam Flood News: Floods situation in Assam gradually improving; 2.72 lakh people still affected | India News - Times of India\nvia The Times of India https://t.co/ZP2hHhqvDN',
#   'CNode_news',
#   0,
#   0,
#   'nr Cambridge, UK'],
#  [datetime.datetime(2023, 6, 27, 10, 23, 7, tzinfo=datetime.timezone.utc),
#   1673638079310036992,
#   '@dr_shipmen @LBC @mrjamesob 🤣🤣what a pathetic argument. Are you forgetting Britain ruled those countries for a long time, and there has been a war between India and Pakistan and war lords, you bell end and all the floods',
#   'fzr600dave',
#   0,
#   0,
#   'United Kingdom'],
#  [datetime.datetime(2023, 6, 27, 10, 5, tzinfo=datetime.timezone.utc),
#   1673633519719923712,
#   '#Flood | Evade illness during #floods by drinking boiled/chlorinated water. https://t.co/iVaWUNdohR',
#   'ndmaindia',
#   4,
#   1,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 27, 9, 59, 1, tzinfo=datetime.timezone.utc),
#   1673632015206477826,
#   'Assam: Local people in Bajali district take shelter on embankments amid heavy flood\n#Assam #Bajali #shelter #embankments #Flood https://t.co/ZTWB2l5Ydz',
#   'timesofindia',
#   16,
#   4,
#   ''],
#  [datetime.datetime(2023, 6, 27, 9, 46, 8, tzinfo=datetime.timezone.utc),
#   1673628774083043333,
#   '⚠️ In flood-affected areas? Please monitor local news and follow the advice of local authorities. \n\n📢 Canadian citizens needing assistance can reach us at: https://t.co/XL49YlOMTk',
#   'CanadainIndia',
#   3,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 9, 43, 21, tzinfo=datetime.timezone.utc),
#   1673628072694919169,
#   'Chennai’s Flood Management Is Commendable But Incomplete https://t.co/ZrFXT0rQqJ',
#   'IndiaInfraHub',
#   10,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 27, 9, 41, 18, tzinfo=datetime.timezone.utc),
#   1673627555549642753,
#   'For how many hours Local Trains services will halt ?\nFor how many hours BEST Bus services will halt ?\nWhere it will flood ?\nWhich Subways will be flooded ?\nWhere are our Citizen Disaster Help Centers ?\netc.\n#Mumbai',
#   'BankiMistry',
#   1,
#   0,
#   'Micro-MSME-Entrepreneur-Mumbai'],
#  [datetime.datetime(2023, 6, 27, 9, 28, 29, tzinfo=datetime.timezone.utc),
#   1673624329420959744,
#   'Chandigarh-Manali Highway Reopens\nhttps://t.co/kRM8PwG4nD\n#chandigarh #manali #highway #reopens #national #commuters #emergency #operation #incidents #maximum #landslides #heavy #downpour #floods #thunderstorms #places #heavy #rainfall #night',
#   'Timesmagazine01',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 8, 48, 59, tzinfo=datetime.timezone.utc),
#   1673614388287139841,
#   'News18 India: 🔴LIVE: Monsoon | Heavy Rain | Landslides | Flood | Delhi Loot | Russia Ukraine War | ICC World Cup\n\nhttps://t.co/UUWHzVS2Xb \n\n#NewsInVids #NewsInVidsIn #NewsInVidsIndia #NewsVideos #NewsInVideos',
#   'newsinvidsin',
#   0,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 8, 32, tzinfo=datetime.timezone.utc),
#   1673610114979299332,
#   '#Flood | Do you how to be prepared for floods?\n\n#FloodsPreparedness https://t.co/BYoEZbtmEn',
#   'ndmaindia',
#   10,
#   9,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 27, 8, 27, 39, tzinfo=datetime.timezone.utc),
#   1673609020299411456,
#   'Himachal Pradesh Flash floods, Landslides, Rains wreak havoc; two killed | Shimla News - Times of India\nvia The Times of India https://t.co/vStnk3EsUv',
#   'CNode_news',
#   0,
#   0,
#   'nr Cambridge, UK'],
#  [datetime.datetime(2023, 6, 27, 8, 7, 45, tzinfo=datetime.timezone.utc),
#   1673604012619476992,
#   '🇦🇺 was pleased to support humanitarian partners @ippf &amp; @FPA_India who provided emergency reproductive &amp; health services to communities impacted by floods in #Kerala &amp; #Chennai &amp; #COVID. Dep CG David met with them to discuss priorities benefiting communities &amp; especially women. https://t.co/AVJ3ae2vZv',
#   'AusCGChennai',
#   21,
#   3,
#   'Chennai, India'],
#  [datetime.datetime(2023, 6, 27, 7, 59, 12, tzinfo=datetime.timezone.utc),
#   1673601861633421313,
#   'The overall #flood situation in #Assam improved on Tuesday following a decrease in rainfall in various parts of the state, authorities ASDMA said, adding that 99 relief camps across eight districts are housing 2,915 individuals.\n\n#AssamFloods https://t.co/I3yS2qZ5MI',
#   'ians_india',
#   0,
#   1,
#   'New Delhi'],
#  [datetime.datetime(2023, 6, 27, 7, 10, 42, tzinfo=datetime.timezone.utc),
#   1673589656292847616,
#   '@narendramodi I feel bad to see my Hon’ble Prime Minister doing the role of a Station Master than a role of Statesman. As a PM, people of India expect that you must appeal for peace in Manipur, assess the flood situation in Assam and Himachal Pradesh.',
#   'Sumitasha007',
#   1,
#   0,
#   'Jagdalpur, India'],
#  [datetime.datetime(2023, 6, 27, 6, 50, 17, tzinfo=datetime.timezone.utc),
#   1673584518991585281,
#   '@kekhaunter @CharlieJamieVed @RAJESH_B_7 @AbhishBanerj Before those India had long history of famines , floods , drought.\nBut then if ppl decide to close their eyes to FACTS against propaganda , whats the point',
#   'kartik_chau',
#   0,
#   0,
#   'New Delhi, India'],
#  [datetime.datetime(2023, 6, 27, 6, 47, 50, tzinfo=datetime.timezone.utc),
#   1673583903419043840,
#   "What @fortune @BJZweig doesn't grasp is the disruption to communities when you flood them with #h1b techies (85% from India + arranged marriages)\n\nSeattle + SF suburbs seeing the flight of US born as #h1b flood in. \n\nBTW larger families cost more than they pay in school taxes",
#   'WATechMillenial',
#   1,
#   0,
#   'PNW, USA'],
#  [datetime.datetime(2023, 6, 27, 6, 38, 18, tzinfo=datetime.timezone.utc),
#   1673581502079152129,
#   'The Weather Channel | Four Die As Flash Floods, Landslides Wreck Uttarakhand, Himachal; Houses, Cars Damaged, Kedarnath Yatra Halted - The Weather Channel\nhttps://t.co/h1cTFU7y29\n\n#AllTheNewsIndia #BreakingNews #BreakingNewsIndia',
#   'AllTheNewsIndia',
#   0,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 6, 23, 20, tzinfo=datetime.timezone.utc),
#   1673577736005091334,
#   'Floods and Heavy Rains Destroy Homes in Nigeria\n\nResidents of Abuja, Nigeria have been seen on submerged streets, trying to salvage their belongings after devastating floods. \n\nThe floods destroyed homes, damaged vehicles, and left locals struggling in the aftermath.\n\n#Nigeria #Flood',
#   'RT_India_news',
#   5,
#   1,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 6, 5, 57, tzinfo=datetime.timezone.utc),
#   1673573360838787074,
#   "#Monsoon hits India's common man hard, flash #floods in hilly states water logging at urban centres. The monsoon has now spread over 80% of #India.\n\n#WATCH on #News9\nhttps://t.co/HE3G4ivaQc\n\n@VergheseScribe @tweettweettalk https://t.co/P3nnPZ3mqz",
#   'News9Tweets',
#   0,
#   0,
#   'NOIDA'],
#  [datetime.datetime(2023, 6, 27, 6, 1, 39, tzinfo=datetime.timezone.utc),
#   1673572277697347586,
#   'Deadly Rains Kill Nine and Leave Hundreds Stranded in #HimachalPradesh\n\n300+ roads closed & 140 power transformers hit by Cloudbursts, flash floods, and landslides with losses up to $12.5mn.\n\nThe state govt has identified 350 hot spots which are landslide prone and issued warnings to the local population and tourists to prioritize safety.\n\n#Rainfall #Landslide \n\n📹 Via @virdiparaminder',
#   'RT_India_news',
#   2,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 5, 17, 5, tzinfo=datetime.timezone.utc),
#   1673561061843255296,
#   'The Pangi-Killar Highway (SH-26) has been blocked due to flash floods in Dared Nala, the Himachal Pradesh State Disaster Response Force said.\n#HimachalPradesh #News #FlashFloods \nhttps://t.co/BB8Y145UcQ',
#   'IndiaToday',
#   6,
#   1,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 5, 16, 37, tzinfo=datetime.timezone.utc),
#   1673560948307808257,
#   '@ChithraMadhavan Simply a story of ancient migration from the land of Udumbara forest in ancient India to Tamilnadu after the great flood. Udumbara is not a golden lizard, it is the name of a fruit whose juice produces gold. Many wonderful stories are attached to this Place.',
#   'AkhilKumarSaho8',
#   3,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 27, 4, 47, 8, tzinfo=datetime.timezone.utc),
#   1673553526981804032,
#   "@Mihir_The1 @marinebharat Just wait for 5 years, when millions of refugees will flood streets of European countries then let's see how countries can afford universal healthcare &amp; free education.",
#   'indian_2030',
#   1,
#   0,
#   'Twitter'],
#  [datetime.datetime(2023, 6, 27, 4, 6, 38, tzinfo=datetime.timezone.utc),
#   1673543334122643458,
#   '#insurance\nAgriculture in India is highly susceptible to risks like droughts and floods.  Risk is inherent in agriculture since the production process takes place...  @ Rs.290\nBLUEROSE STORE\nhttps://t.co/3f0gX2E2Kx\nAMAZON\nhttps://t.co/P3Kb79lpx9\nFLIPKART\nhttps://t.co/tRtRQ3KTbu https://t.co/jAUY59Fd8H',
#   'RanaJagendra',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 27, 4, 1, 17, tzinfo=datetime.timezone.utc),
#   1673541988103380994,
#   'I feel bad to see my Hon’ble Prime Minister doing the role of a Station Master than a role of Statesman.\n\nAs a PM, people of India expect that you must appeal for peace in Manipur, assess the flood situation in Assam, deteriorating social fabric in Uttarkhand and sensitive security situation in J&K incl Ladakh and Arunachal Pradesh.',
#   'ColDiptangshu',
#   108,
#   10,
#   'INDIA'],
#  [datetime.datetime(2023, 6, 27, 3, 31, 50, tzinfo=datetime.timezone.utc),
#   1673534577359347712,
#   'Nearly half of South Africa’s world-renowned Kruger National Park (KNP) will be burnt in controlled fires to protect the ecosystem after floods and heavy rains this season. https://t.co/eGyYDs3SfK',
#   'NH_India',
#   1,
#   1,
#   'New Delhi, India'],
#  [datetime.datetime(2023, 6, 27, 3, 5, 45, tzinfo=datetime.timezone.utc),
#   1673528013777141764,
#   'The busy Chandigarh-Manali highway, where hundred of tourists have been stuck for over 24 hours, was among 301 roads closed in Himachal Pradesh since Sunday because of landslides and flash floods. \n\nThe alternative route of Kullu-Bajaura-Kataula-Mandi was blocked too.\nhttps://t.co/UiHgEIXHXH',
#   'timesofindia',
#   26,
#   3,
#   ''],
#  [datetime.datetime(2023, 6, 27, 2, 39, 16, tzinfo=datetime.timezone.utc),
#   1673521345995612160,
#   'Things that can kill you in India 1857 and India 2023:\n\nRabies\nMalaria\nElectrocution at Railway Station\nTalking critically about the ruler\nSudden flood after 3 minutes rain',
#   'jerxn_',
#   3,
#   3,
#   ''],
#  [datetime.datetime(2023, 6, 27, 0, 57, 43, tzinfo=datetime.timezone.utc),
#   1673495790181060608,
#   'Flash floods, landslides and lightning strikes triggered chaos in several states as the monsoon blanketed much of India in a sudden surge, leaving at least 10 people dead and scores stranded on highways\n\nhttps://t.co/NdiDr5bk0p',
#   'htTweets',
#   7,
#   2,
#   'India'],
#  [datetime.datetime(2023, 6, 27, 0, 46, 2, tzinfo=datetime.timezone.utc),
#   1673492853539082240,
#   'Monsoon fury wreaks #havoc across #India, millions affected\n\nThe India Meteorological Department (IMD) has predicted heavy rainfall in several states, including Assam, Maharashtra, Himachal Pradesh, and Jammu and Kashmir. The flood…https://t.co/b9L5O5tQDl https://t.co/CnvHWGEskn',
#   'rameshkotnana1',
#   0,
#   0,
#   'Hyderabad, India'],
#  [datetime.datetime(2023, 6, 27, 0, 38, 19, tzinfo=datetime.timezone.utc),
#   1673490907721527296,
#   'The Weather Channel | Four Die As Flash Floods, Landslides Wreck Uttarakhand, Himachal; Houses, Cars Damaged | https://t.co/nJbKoVkOSP - The Weather Channel\nhttps://t.co/h1cTFU7y29\n\n#AllTheNewsIndia #BreakingNews #BreakingNewsIndia',
#   'AllTheNewsIndia',
#   0,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 26, 22, 34, 54, tzinfo=datetime.timezone.utc),
#   1673459852281012224,
#   'Heavy rains hit the city of Ahmedabad, India, causing flooding for at least the second time this month. Deadly rains and floods in the Indian state of Gujarat have become more common in recent years, with over 225 people dying after heavy rains hit the area in 2017.\n\n#CGTNAmerica https://t.co/pvCywXVJRo',
#   'CGTNOfficial',
#   8,
#   8,
#   'Beijing, China'],
#  [datetime.datetime(2023, 6, 26, 22, 34, 26, tzinfo=datetime.timezone.utc),
#   1673459735113203720,
#   'Heavy rains hit the city of Ahmedabad, India, causing flooding for at least the second time this month. Deadly rains and floods in the Indian state of Gujarat have become more common in recent years, with over 225 people dying after heavy rains hit the area in 2017. https://t.co/s6nzmLbctD',
#   'cgtnamerica',
#   3,
#   1,
#   'Washington, DC'],
#  [datetime.datetime(2023, 6, 26, 21, 44, tzinfo=datetime.timezone.utc),
#   1673447040469336064,
#   "@BlackKnight10k NSWER TO THE PROBLEMEXILE BIDEN TO RED CHINA!FLOODS HAVE WIPED OUT RED CHINESE RICE PADDIES....DON'T SEND THEM RICE FROM CALIFORNIA;BECAUSE CALIFORNIA PRODUCES MORE RICE THAN ALL OF THE ASIAN COUNTRIES PUT TOGETHER,,THAT'S PHILLIPINES,INDIA,CHINA,MALAYSIA,VIETNAM ,CAMBODIA ETC",
#   'eldoradoreef',
#   0,
#   0,
#   'rancho palos verdes,calif.'],
#  [datetime.datetime(2023, 6, 26, 21, 30, tzinfo=datetime.timezone.utc),
#   1673443517681614849,
#   'Photos: Traffic nightmare after flash floods, landslides in #HimachalPradesh, #India \n\nTailbacks stretch for miles as commuters get stalled for hours\n\nhttps://t.co/fr458BSAh1',
#   'gulf_news',
#   3,
#   2,
#   'United Arab Emirates'],
#  [datetime.datetime(2023, 6, 26, 18, 59, 15, tzinfo=datetime.timezone.utc),
#   1673405580227010562,
#   '@Keir_Starmer @IGFupdates What contribution?\nName one!\nIndia chose to build up a massive armed services, a nuclear arsenal and a space program before attempting to feed its population; hence many flood our Kent beaches!\nA government firmly in bed with Putin!\nNot a friend; you can stick your partnership!',
#   'mike1963payne',
#   5,
#   1,
#   'Planet Earth'],
#  [datetime.datetime(2023, 6, 26, 18, 15, 4, tzinfo=datetime.timezone.utc),
#   1673394462397964295,
#   '@GBNEWS 10,000 in 5 months that we know about\nSUNAK LEADER LAMMY &amp; KHAN WILL FLOOD THE UK WITH ILLEGALS &amp; THE WORLD\nQUICKER BY BOAT ISLAM BLM &amp; NOW INDIA RULE GENOCIDE OF THE ENGLISH IS WELL UNDERWAY YOUR LEADER IS TAKING IN A FURTHER 3000 EVERY YEAR FROM INDIA https://t.co/xgMJ61mNeW',
#   'corrupt91256467',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 18, 8, 43, tzinfo=datetime.timezone.utc),
#   1673392865647403011,
#   '@Scarfer13 @GBNEWS SUNAK YOUR INDIAN LEADER WITH LAMMY &amp; KHAN WILL FLOOD THE UK WITH ILLEGALS &amp; THE WORLD\nQUICKER BY BOAT ISLAM BLM &amp; NOW INDIA RULE GENOCIDE OF THE ENGLISH IS WELL UNDERWAY YOUR LEADER IS TAKING IN A FURTHER 3000 EVERY YEAR FROM INDIA https://t.co/xgMJ61mNeW',
#   'corrupt91256467',
#   2,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 18, 8, 22, tzinfo=datetime.timezone.utc),
#   1673392777172865024,
#   '@GBNEWS SUNAK YOUR INDIAN LEADER WITH LAMMY &amp; KHAN WILL FLOOD THE UK WITH ILLEGALS &amp; THE WORLD\nQUICKER BY BOAT ISLAM BLM &amp; NOW INDIA RULE GENOCIDE OF THE ENGLISH IS WELL UNDERWAY YOUR LEADER IS TAKING IN A FURTHER 3000 EVERY YEAR FROM INDIA https://t.co/xgMJ61mNeW',
#   'corrupt91256467',
#   1,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 17, 30, tzinfo=datetime.timezone.utc),
#   1673383120567934988,
#   "#IMD issues warnings for unpredictable weather patterns, including flash #floods in northern regions.  \n\nHere's how to prepare for them  \n\n#weather #India #FlashFloods\nhttps://t.co/tVyKILo4S0",
#   'bsindia',
#   6,
#   1,
#   'India'],
#  [datetime.datetime(2023, 6, 26, 17, 26, 19, tzinfo=datetime.timezone.utc),
#   1673382194788839425,
#   "@haris_blr @Ask_koppal @marinebharat These takes are so retarded. Most of them haven't stepped outside India. One city is a choking hazard, the other floods for a good 2 months. Everything's littered and smells bad but bro QOL outside India is not that great 🤡",
#   'kuttan123321',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 16, 59, 50, tzinfo=datetime.timezone.utc),
#   1673375528764735489,
#   "Hon'ble MLAs Sushanta Borgohain and Manab Deka Donate One Month's Salary to Assam Flood Relief Fund  #AssamFloods #Assam #Donate\nRead Here 👇\nhttps://t.co/cv5fyXbkox https://t.co/KBRaYJQL6x",
#   'newsnortheastin',
#   1,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 16, 35, tzinfo=datetime.timezone.utc),
#   1673369278291251202,
#   "Know more about Flood Prevention, Preparedness &amp;Mitigation, Flood Forecasting and Warning in India in the \n@ndmaindia 's guidelines on the management of #Floods: https://t.co/kY9SdDUDzf\n\n#FloodsManagement https://t.co/bS9bngPVcH",
#   'ndmaindia',
#   7,
#   2,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 16, 20, 57, tzinfo=datetime.timezone.utc),
#   1673365743218606081,
#   'Himachal Flash Floods: Chandigarh-Manali national highway blocked\n\n#india #himachal #HimachalWeather\n#Flood #floods\nhttps://t.co/L8iVLSG5di',
#   'SAAjaySingh1',
#   0,
#   0,
#   'Kanyakumari,India'],
#  [datetime.datetime(2023, 6, 26, 16, 10, 59, tzinfo=datetime.timezone.utc),
#   1673363234785751041,
#   '@BengalGovernor Sir,monsoon come in Bengal alongwith other states. In Kolkata d Suorage system is too much bad.Flood is covered 50%of India. In Kolkata 98% Drain r covered with garbage.Immediately it must b cleared. It should b clear twice a week otherwise Kolkata will b flooded.',
#   'RATANKU21342615',
#   0,
#   0,
#   'Kolkata, India'],
#  [datetime.datetime(2023, 6, 26, 16, 10, 30, tzinfo=datetime.timezone.utc),
#   1673363115172564992,
#   '@geetashrilachit What time chance was to solve Assam Flood 4-5 decades ago,that time we do not take any action only by creating Flood Control Dept,Our ex Agri Minister Late Nilomoni Das(US based Agriculture Scientist)that time alerted, Now India,China n Bangladesh.... @sarat65neog @Lucas_ACS2021',
#   'rituparnasarm10',
#   2,
#   0,
#   'Assam,Bharat Rashtra'],
#  [datetime.datetime(2023, 6, 26, 16, 6, tzinfo=datetime.timezone.utc),
#   1673361980197945344,
#   '#Floods | Move to higher ground if you need to evacuate during #floods. https://t.co/FAVi6ABmOl',
#   'ndmaindia',
#   5,
#   2,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 15, 48, 10, tzinfo=datetime.timezone.utc),
#   1673357494159278080,
#   'Flood preparedness workshop for student volunteers at the Centre for Wildlife Rehabilitation and Conservation, Assam.\n\nThese volunteers would be on stand-by to help us address flood related wildlife rescues and emergencies in the coming weeks.\n\n@HCL_Foundation\n@ifawglobal https://t.co/jTUfrtAWi3',
#   'wti_org_india',
#   11,
#   0,
#   'New Delhi'],
#  [datetime.datetime(2023, 6, 26, 15, 35, tzinfo=datetime.timezone.utc),
#   1673354178788466690,
#   "#Floods| Don't enter deep waters during floods, use a stick to check the depth of water. https://t.co/VxarmvWUe5",
#   'ndmaindia',
#   7,
#   3,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 15, 33, 49, tzinfo=datetime.timezone.utc),
#   1673353880606834689,
#   'According to the Assam Daily Flood Report, 5 lives have been lost due to the devastating floods as on June 26. A total of 155,896 people have been affected, with Barpeta, Bajali, and Lakhimpur districts facing the highest impact. \n\n#AssamFloods\n\nhttps://t.co/InJMgWkef8',
#   'IndiaTodayNE',
#   1,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 15, 5, tzinfo=datetime.timezone.utc),
#   1673346629246803968,
#   "While evacuating during #floods, Don't ignore your animals either take your animals/pets with you or untie them. https://t.co/hAlToQiLWW",
#   'ndmaindia',
#   4,
#   1,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 14, 48, 1, tzinfo=datetime.timezone.utc),
#   1673342354248413185,
#   "@FreezePeach22 All the authorities deny it but all the authorities admit to having used it. It's fucking nuts.\nLondon is always being blasted.\nYou can hire people to do it.\nIt's caused floods in the middle east and India, at least.\nAll searchable facts.",
#   'Excalibur890',
#   1,
#   0,
#   'London, 🏴\U000e0067\U000e0062\U000e0065\U000e006e\U000e0067\U000e007f '],
#  [datetime.datetime(2023, 6, 26, 14, 42, 23, tzinfo=datetime.timezone.utc),
#   1673340938997882880,
#   '💡 "The days of financing #flood and #drought risk separately are over." \n\n- Mr. Greg Browder, @WorldBank Lead Water Resources Management Specialist at GWP India workshop 👉https://t.co/0N3HzNP3Ou   \n\n#EPICresponse @GWPSAS @deltares @WMO https://t.co/8tVLXhpRrU',
#   'GWPnews',
#   2,
#   0,
#   'Stockholm, Sweden'],
#  [datetime.datetime(2023, 6, 26, 14, 41, 58, tzinfo=datetime.timezone.utc),
#   1673340834912129028,
#   'New Delhi/Shimla/Jaipur: Lightning struck Rajasthan on Monday, killing at least four people and leaving hundreds stranded in Himachal Pradesh as monsoon rains caused floods, landslides and road blocks in some parts of northern and western India.  .\n\nhttps://t.co/jY0WijIXIV https://t.co/wOW5k8i8QJ',
#   'EditorCCNews',
#   0,
#   0,
#   'Sitapur, India'],
#  [datetime.datetime(2023, 6, 26, 14, 41, 46, tzinfo=datetime.timezone.utc),
#   1673340781510180864,
#   '@jaamboree @eShailendra @mjeyachandran6 @FriedrichPieter @elonmusk The 9 year RSS flood has reversed to ebb, &amp; that critical tipping point has been crossed. It’s obvious that Indian voters, esp rural/semi rural, have seen through the feckless propaganda of a shallow Modi &amp; @BJP4India’s IT cell. India has ~year’s momentum to solidify BJPs demise!',
#   'TrivedParth',
#   0,
#   0,
#   'Canada'],
#  [datetime.datetime(2023, 6, 26, 14, 35, tzinfo=datetime.timezone.utc),
#   1673339079339941891,
#   '#Flood | Watch your step during #floods. https://t.co/e39yqOHdD7',
#   'ndmaindia',
#   7,
#   2,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 14, 34, 49, tzinfo=datetime.timezone.utc),
#   1673339034993668099,
#   '@AndersSjastad Did they mention that both India and China have hankering for cheap crude, and that while India has replaced EU in a beholden-to-Russia relationship, China is independent and can flood markets to keep oil price capped? 😃🙏',
#   'Vmaxpax',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 14, 26, 9, tzinfo=datetime.timezone.utc),
#   1673336851275325440,
#   '#Assam: Flood situation has further improved due to better weather conditions but more than 1,55,000 people of 563 villages are still reeling under the deluge across 23 revenue circles. Two persons have lost their lives in #Barpeta district today.\n\nThe State government has closed several #reliefcamps though 2915 people are still in 29 relief camps. Seventy relief distribution centres are in operation in the flood-affected districts.\n\n#AssamFloods',
#   'airnewsalerts',
#   11,
#   5,
#   'New Delhi, India'],
#  [datetime.datetime(2023, 6, 26, 14, 15, 23, tzinfo=datetime.timezone.utc),
#   1673334145236234241,
#   'Flash floods, landslides, rains wreak havoc in Himachal Pradesh, India - six dead\n\nhttps://t.co/5jOOjPKlAQ',
#   'TruthDaily_1',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 26, 14, 7, 50, tzinfo=datetime.timezone.utc),
#   1673332244205764609,
#   'After arriving from USA &amp; Egypt. Modi ji asking- Whats Happening in India? When Nero was away, Manipur was burning. Assam is reeling under floods. BJP is denying rice to Karnataka. As usual, Muslims are being lynched in Maharashtra. Baaki Sab Changa Sii. #Vishwaguru PM #Congress',
#   'Mumbai_Citizens',
#   0,
#   0,
#   'Mumbai City,Maharashtra'],
#  [datetime.datetime(2023, 6, 26, 14, 6, tzinfo=datetime.timezone.utc),
#   1673331780731179008,
#   "#Flood | Drink Chlorinated Water During #Floods. Here's how to Chlorinate Water. https://t.co/d1r3PLvphs",
#   'ndmaindia',
#   17,
#   4,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 13, 59, 44, tzinfo=datetime.timezone.utc),
#   1673330205371269122,
#   '@The_Astromancer @ninaturner @TIME Yea keep dreaming bro. “On the ground in India” is a lot of peoples version of hell because it’s a terrible place. Objectively.  Let me know when you have running water and actual Infrastructure. In India it rains and the streets flood every time, entire cities. It’s pathetic',
#   'Tortoises345',
#   0,
#   0,
#   'United States'],
#  [datetime.datetime(2023, 6, 26, 13, 34, tzinfo=datetime.timezone.utc),
#   1673323728208273410,
#   '#Floods| Watch out for broken electric poles and wires, sharp objects etc. during floods. https://t.co/70ul1ABIX1',
#   'ndmaindia',
#   3,
#   0,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 13, 18, 57, tzinfo=datetime.timezone.utc),
#   1673319941913870342,
#   'Heavy rains are expected in central India this week due to low pressure. Will bring flood outflows to Godavari River 👍🌊 https://t.co/9Qt4ZuZM6x',
#   'VizagWeather247',
#   87,
#   4,
#   'Gajuwaka, Visakhapatnam'],
#  [datetime.datetime(2023, 6, 26, 13, 7, tzinfo=datetime.timezone.utc),
#   1673316933310054400,
#   '#Flood | During #Floods, what should you do?\n\nIf you need to evacuate, put sandbags in your toilet bowl and cover all drain holes to prevent sewage backflow. https://t.co/9G6UHOdmyB',
#   'ndmaindia',
#   6,
#   2,
#   'New Delhi-110029'],
#  [datetime.datetime(2023, 6, 26, 12, 38, 20, tzinfo=datetime.timezone.utc),
#   1673309718318546947,
#   'The Tribune India | Himachal flash floods: Hundreds of commuters stranded as Chandigarh-Manali national highway blocked - The Tribune India\nhttps://t.co/hurwQvIN6c\n\n#AllTheNewsIndia #BreakingNews #BreakingNewsIndia',
#   'AllTheNewsIndia',
#   0,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 26, 12, 36, tzinfo=datetime.timezone.utc),
#   1673309131661520898,
#   "Before #Floods :: Do's &amp; Don'ts\n\nKeep Drains Clean! https://t.co/VUSZQ9D5zQ",
#   'ndmaindia',
#   5,
#   2,
#   'New Delhi-110029'],
# ...
#   'Weather office warns of floods as India, Pakistan brace for cyclone https://t.co/89jmVzus8T',
#   'Mystartweather',
#   0,
#   0,
#   'Redmond, WA'],
#  [datetime.datetime(2023, 6, 14, 12, 50, 21, tzinfo=datetime.timezone.utc),
#   1668964088599449601,
#   'Weather office warns of floods as India, Pakistan brace for cyclone - By @summitkhanna, @Rajendra1857  https://t.co/6b1sNBwiy0 via @theprintindia',
#   'MayankBhardwaj9',
#   0,
#   1,
#   'New Delhi'],
#  [datetime.datetime(2023, 6, 14, 12, 14, 44, tzinfo=datetime.timezone.utc),
#   1668955125791031296,
#   'Biparjoy: India, Pakistan evacuate thousands ahead of cyclone\n\nPakistan is still reeling from the aftermath of the devastating 2022 floods which submerged large parts of the country and killed almost 1,700 people. \u2066@MerylinSam\u2069  https://t.co/IoEQun12YT',
#   'BasuAshis',
#   0,
#   1,
#   'Canada'],
#  [datetime.datetime(2023, 6, 14, 11, 6, 23, tzinfo=datetime.timezone.utc),
#   1668937924086202368,
#   '@bamwinejnr USA floods, Saudi floods, UAE floods, Oman Floods, India floods. What does it have to do with leaders',
#   'MuhamadAhmadAb1',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 14, 10, 47, 49, tzinfo=datetime.timezone.utc),
#   1668933253875507201,
#   'This is really good solution which has tested in Norway today. We need it in India too!\n\nIn the emergency situation you’ll get direct alert on your phone.\n\nIt’s very helpful to guide citizens what to do in situations like:\n\n• Flood\n• Earthquake\n• Fire in the Forest\n• Or War https://t.co/GF04VqJGMg',
#   'imayurj',
#   4,
#   0,
#   'Visual content →'],
#  [datetime.datetime(2023, 6, 14, 10, 17, 59, tzinfo=datetime.timezone.utc),
#   1668925743450009600,
#   '@Eesy20 @GrandadofOscar Israel leads the way in growing food in the desert.  Making deserts bloom and all that.  It shares that technology with countries in Africa, with India, and other places around the world.  \n\nIsrael is also developing ways to grow food in flood prone areas.',
#   'shira39503',
#   29,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 14, 9, 50, 42, tzinfo=datetime.timezone.utc),
#   1668918880256028675,
#   'CYCLONE ALERT: 🌀#CycloneBiparjoy is approaching the India-Pakistan border region, bringing potential #floods and power disruptions in its wake. Landfall predicted on Thursday. #satellite #Karachi #Gujarat   Track the cyclone at - https://t.co/aWBA3mrCu6',
#   'amansid85658091',
#   5,
#   4,
#   ''],
#  [datetime.datetime(2023, 6, 14, 9, 8, 40, tzinfo=datetime.timezone.utc),
#   1668908301265043456,
#   'Musl!m man wishing harm &amp; death to innocent Hindus of Uttrakhand through floods like 2013. \n\nSome Hindus still want Bhaichara &amp; secular India with these barbaric community. https://t.co/e7fTw6WdiL',
#   'LiberalHinduA',
#   295,
#   116,
#   ''],
#  [datetime.datetime(2023, 6, 14, 8, 39, 49, tzinfo=datetime.timezone.utc),
#   1668901042011148288,
#   '#India | Cyclone Biparjoy: IMD warns of floods, power outage this week in cyclone-hit regions https://t.co/1nxmTjV87w via @NewsLiveGhy \n\n#CycloneBiparjoy #IMD #floods #cyclone',
#   'NewsLiveGhy',
#   6,
#   0,
#   'Guwahati, India'],
#  [datetime.datetime(2023, 6, 14, 8, 38, 19, tzinfo=datetime.timezone.utc),
#   1668900661591932928,
#   '@PTI_News @PIB_India why are you silent on Manipur &amp; Farmers protest on highway news coverage \nWho cares gangsters Gujarat floods or I T.rides untill now no culprits have arrested or punished or recovered just showing on media4political milage&amp;showing power kick⭕️ Value agencies',
#   'Sudharaniathyd',
#   1,
#   1,
#   'Hyderabad '],
#  [datetime.datetime(2023, 6, 14, 8, 1, 8, tzinfo=datetime.timezone.utc),
#   1668891305282351106,
#   "@lukn4alonexta @DaraOgunto @ebereosuagwu @Orji_Okosisi1 yes. atleast it's in nigeria. we don't go to other people country to flood their countries with drugs. aside saudi name other countries where u see yoruba pple caught with drugs. but can same be said abt u guys? frm india,malaysia,indonasia,southy,kenya,brazil 2 numerous 2 name.",
#   'lukmansegun_',
#   1,
#   0,
#   'Lagos, Nigeria'],
#  [datetime.datetime(2023, 6, 14, 8, 0, 25, tzinfo=datetime.timezone.utc),
#   1668891124138745856,
#   'CYCLONE ALERT: 🌀#CycloneBiparjoy is approaching the India-Pakistan border region, bringing potential #floods and power disruptions in its wake. Landfall predicted on Thursday. #satellite #Karachi #Gujarat \n\nTrack the cyclone at - https://t.co/Z9B6jSwSGH https://t.co/Uk9QnQe4rF',
#   'Windycom',
#   177,
#   37,
#   'Prague'],
#  [datetime.datetime(2023, 6, 14, 7, 59, 57, tzinfo=datetime.timezone.utc),
#   1668891010087391234,
#   '#banking\n#economy\n#NER\n1. India bank unions ask RBI to withdraw compromise settlement for wilful defaulters\n2. Assam: First Wave of Flood Hits Assam, IMD Forecasts Heavy Rainfall\n3. Manipur violence: Over 47,000 evacuated, CM assures help\n\nhttps://t.co/BZ36IYIhxa',
#   'IIBMGuwahati',
#   2,
#   0,
#   'Khanapara, Guwahati 781022 '],
#  [datetime.datetime(2023, 6, 14, 7, 0, 45, tzinfo=datetime.timezone.utc),
#   1668876110346735616,
#   '@univedsports Unived India is a spam and fraud. No customer service no, no way to review  on fb. If it really is this way I will flood you f****like on social media',
#   'Damuscus17',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 14, 6, 59, 58, tzinfo=datetime.timezone.utc),
#   1668875911905824768,
#   '@univedsports Unived India is a spam and fraud. No customer service no, no way to review  on fb. If it really is this way I will flood you f****like on social media',
#   'Damuscus17',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 14, 4, 8, 36, tzinfo=datetime.timezone.utc),
#   1668832787426865152,
#   'Come on India- When big brands succeed it opens flood of opportunities in the sector. Keep an eye on EMS companies https://t.co/VrWbolZTTR',
#   'rambaranwal',
#   1,
#   0,
#   'Noida, India'],
#  [datetime.datetime(2023, 6, 14, 3, 27, 52, tzinfo=datetime.timezone.utc),
#   1668822537927532545,
#   '#CycloneBiparjoyUpdate: IMD warns of flood, power disruption; trains cancelled |\nhttps://t.co/eHWIucVux0\n\n#India #IMD #BiparjoyCyclone',
#   'mkyuniversal',
#   1,
#   0,
#   'Everywhere '],
#  [datetime.datetime(2023, 6, 14, 1, 30, 28, tzinfo=datetime.timezone.utc),
#   1668792989404020736,
#   '#Peru s/sentido de urgencia frente al #CambioClimatico. “Glacial lake outburst floods threaten millions globally | Nature Communications “More than half of the globally exposed population are found in just four countries: India, Pakistan, #Peru, and China” https://t.co/GyL6arxEFg',
#   'vozdelatierra',
#   5,
#   5,
#   ''],
#  [datetime.datetime(2023, 6, 14, 1, 23, 2, tzinfo=datetime.timezone.utc),
#   1668791121437155330,
#   'Cyclone Biparjoy: IMD warns of flood, power disruption; trains cancelled | Latest News India https://t.co/U9Y38ZoWGh \nhttps://t.co/U9Y38ZoWGh',
#   'Realtime_india',
#   0,
#   0,
#   'india'],
#  [datetime.datetime(2023, 6, 14, 1, 22, 13, tzinfo=datetime.timezone.utc),
#   1668790916965093376,
#   '#insurance\nAgriculture in India is highly susceptible to risks like droughts and floods. It is necessary to protect the farmers from natural calamities. @ Rs.290\nBLUEROSE STORE\nhttps://t.co/3f0gX2E2Kx\nAMAZON\nhttps://t.co/8pDjBcOVgO\nFLIPKART\nhttps://t.co/tRtRQ3KTbu https://t.co/VODJ67auLd',
#   'RanaJagendra',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 13, 23, 58, 15, tzinfo=datetime.timezone.utc),
#   1668769784916512768,
#   'Climate change and extreme weather condition effects: Wildfires in North America, flood in India/Bangladesh, drought in Central America.',
#   'Zuby215',
#   1,
#   0,
#   'YKF'],
#  [datetime.datetime(2023, 6, 13, 22, 14, 21, tzinfo=datetime.timezone.utc),
#   1668743636324941825,
#   '@brainratz But I thought he was a socialist? Why would he do that? \nMy Grandfather George Blair was named after his cousin Eric Blair. \nEric began to see the issue as his father ran the production of Opium out of India which was used to flood China …..\nJust like China is doing to us now',
#   'thegistofitis',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 13, 20, 2, 7, tzinfo=datetime.timezone.utc),
#   1668710361237970944,
#   '30,000 residents evacuated to temporary shelters in flood-affected regions; Joint efforts by the Army and NDRF underway for relief operations. \n#NDRF #India #CycloneBiparjoy #CycloneBiparjoyUpdate #CycloneAlert #gujratcyclone #Karachi #India #Pakistan #greentimemedia https://t.co/jN43iffGij',
#   'greentime_media',
#   2,
#   0,
#   'Dhaka, Bangladesh'],
#  [datetime.datetime(2023, 6, 13, 17, 21, 46, tzinfo=datetime.timezone.utc),
#   1668670007574769682,
#   "@Danielsrotaryo1 @JustAFamilyMan_ That's not how US immigration works. There's been a flood of Ukranians coming here as of late, somewhere in the hundreds of thousands.\n\nChina and India still have billions of ppl. SE Asia has half a million ppl. There's plenty of ppl if we want them.",
#   'ScuvyBob',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 13, 16, 50, 35, tzinfo=datetime.timezone.utc),
#   1668662157125496832,
#   "@anandmahindra @nitin_gadkari In India, this can't happen. Because if the water flow goes just beyond the line, the road will become the worst and we can see floods. For this, we have to plan more than this clip.",
#   'AlpaChetana',
#   0,
#   0,
#   'Jamnagar, India'],
#  [datetime.datetime(2023, 6, 13, 16, 46, 32, tzinfo=datetime.timezone.utc),
#   1668661139448926208,
#   '@DilbertDudley @sullivan_larry @stop_fossil_fue @NASA @IPCC_CH World is afraid of flood in Pakistan, nz, drought in Spain, delayed monsoon in India, wildfire in Canada..  The list in endless. We are living the nightmare. Stop defending the old ways. Or are you waiting for someone dear to you to get hurt?',
#   'Politickler1',
#   1,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 13, 13, 56, 49, tzinfo=datetime.timezone.utc),
#   1668618429220421633,
#   'तू डाल डाल ,मैं पात पात ..? \nClean sweep by revered cm of Bihar to make "own medical facility" in DMCH in lieu of AIIMS. North Bihar is known by all to flood affected zone of India not by Bihar. Step behaviour of GOI hurts Mithila. @NitishKumar @SanjayJhaBihar @yadavtejashwi',
#   'Amarnat67109740',
#   0,
#   0,
#   'Mokameh, India'],
#  [datetime.datetime(2023, 6, 13, 13, 53, 17, tzinfo=datetime.timezone.utc),
#   1668617540048936966,
#   '#CycloneBiparjoy \n\nMay Allah Almighty protect Pakistan and India from floods and rains \n\n#CycloneBiparjoy #Pakistan #Karachi #earthquake #Rain https://t.co/LeCt6oDjG1',
#   'ahtisham_sk',
#   57,
#   9,
#   'Lahore, Pakistan'],
#  [datetime.datetime(2023, 6, 13, 13, 0, 54, tzinfo=datetime.timezone.utc),
#   1668604356042555394,
#   'Amit Shah  announced three major schemes worth over Rs 8,000 crore that would cover the modernisation of fire brigade services in all states, flood mitigation in seven major cities and prevention of landslides in 17 \n#Modernisation #India\nhttps://t.co/3OuisFczSF',
#   'newspaperwalla',
#   1,
#   1,
#   'Srinagar, India'],
#  [datetime.datetime(2023, 6, 13, 12, 46, 16, tzinfo=datetime.timezone.utc),
#   1668600672927772672,
#   'Full Story :https://t.co/J65fZS14Mt\nHeavy Rains Caused Flash Floods in Paris France \n#floods#tears#chennai#city#climate#india#tomorrow#thalapathy#years#video#pooja#tamilnadu#story#bristolcity#bristol#man#leicester#manchester#mancity#sunderland#manchestercity#love#climatechange# https://t.co/6CXT9GVtGH',
#   'natural79939854',
#   0,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 13, 11, 52, 22, tzinfo=datetime.timezone.utc),
#   1668587111212261377,
#   '#NewsUpdate | #AmitShah announces three major schemes worth Rs 8,000 crore for disaster management. The schemes will cover the modernization of fire brigade services, flood mitigation, and prevention of landslides.\n\n@AmitShah #DisasterManagement #India #GalattaNews',
#   'galattadotcom',
#   4,
#   0,
#   'Chennai, India'],
#  [datetime.datetime(2023, 6, 13, 11, 30, tzinfo=datetime.timezone.utc),
#   1668581479918567426,
#   'The cyclone is likely the most powerful to hit western India and Pakistan since 2021, and follows devastating floods that ravaged Pakistan last year, leaving 1,739 people dead and $30 billion in losses.\n#India #Pakistan #CycloneBiporjoy\nhttps://t.co/sDRIH5vQ2m',
#   'PeninsulaQatar',
#   0,
#   0,
#   'Qatar'],
#  [datetime.datetime(2023, 6, 13, 11, 28, 10, tzinfo=datetime.timezone.utc),
#   1668581021506318339,
#   'PC also sold currency printing machinery to Pakistan, so that they can flood India with counterfeit notes! @Jairam_Ramesh @Saliltoday @k_kkmallya589 @DrRajeshDBhat @MADHUKAR1303 @ShineHamesha @SubhashiniMenon @16menon @TaraRao0112 @DamodarHegde4 @vivekpai01 @mankuli',
#   'shenoybv',
#   20,
#   9,
#   ''],
#  [datetime.datetime(2023, 6, 13, 11, 19, 27, tzinfo=datetime.timezone.utc),
#   1668578825792524288,
#   '@GorwayGlobal @rjaishankar No Sir. \n\nI am only saying people recover even after Taunami, earthquake, floods etc over a period of time. \n\nIndia already took the hit on GDP at that time &amp; Demo is history. \n\nSo for how long anyone can keep saying that Demo has killed informal sector? Another 100 years?',
#   'GovindarajanV10',
#   0,
#   0,
#   'Chennai, India'],
#  [datetime.datetime(2023, 6, 13, 10, 32, 12, tzinfo=datetime.timezone.utc),
#   1668566933287968769,
#   "#India.Huge waves hit #Gujarat coast in #الهند as 'extremely violent' #Cyclone #Biparjoy approaches after it unleashes over #Pakistan's #Sindh area with high winds,torrential rains and flash floods.1.40 Million People in India and Pakistan will be Exposed https://t.co/8JJNmqtfTY",
#   'doyaksec',
#   1,
#   0,
#   ''],
#  [datetime.datetime(2023, 6, 13, 10, 26, 18, tzinfo=datetime.timezone.utc),
#   1668565451931041795,
#   'Cyclone Biparjoy managed to intensify, which could bring heavy rain and flash flood risk in Pakistan and India. Forecast said that about 80,000 evacuated in Pakistan, while 12,000 in...  #ClimateChange #Nature #STEM #Science https://t.co/b8Uat2uzlE',
#   'NatureWorldNews',
#   0,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 13, 9, 31, 54, tzinfo=datetime.timezone.utc),
#   1668551762066935808,
#   '@AmitShah Today great resolutions for @@AmitShah ji addressing mitting with minister of disaster management states &amp; UTs for india largest coastline, wildfire, mountain state flooded areas, tsunami, and metro city flood impact to national disaster management respond all state activ system',
#   'MyInfo75815757',
#   0,
#   0,
#   'Lusiana, Veneto'],
#  [datetime.datetime(2023, 6, 13, 8, 45, 3, tzinfo=datetime.timezone.utc),
#   1668539969831604224,
#   '"Felt The Shaking?": Query Floods Twitter As Tremors Jolt North India https://t.co/rVTb1XPPEx https://t.co/0JEtjYXZaQ',
#   'ndtvfeed',
#   12,
#   3,
#   ''],
#  [datetime.datetime(2023, 6, 13, 6, 53, 45, tzinfo=datetime.timezone.utc),
#   1668511958973419520,
#   'Dr Rajesh Duvvuru from #India develops device for early #flood detection &amp; #rescue operations.\n\n#floodrush #flooddetection #rescueoperations  #Patente #Patente #intellectualproperty #TechNews #technology #TechnologyNews #techtwitter #techno #TechTrends #TechTuesday #LatestNews https://t.co/zzCFFcCei1',
#   'Bayslopepatent',
#   4,
#   2,
#   'Gurgaon, India'],
#  [datetime.datetime(2023, 6, 13, 6, 22, 41, tzinfo=datetime.timezone.utc),
#   1668504144007823362,
#   'Manufacturing share of India GDP is falling for years, yet we are sold the story that companies moving out of China will flood to India. Nothing of the sort has happened. Only those like me who has set up and run a manufacturing unit know the obstacles and pitfalls.',
#   'goldchest4',
#   6,
#   0,
#   'India'],
#  [datetime.datetime(2023, 6, 13, 4, 55, 13, tzinfo=datetime.timezone.utc),
#   1668482130995982337,
#   '@JeffreyKotyk The very foundation of Tang China was laid down in India. Some of the Christians and Persians went to present China during the time of the flood which happened sometimes in 8-9th AD.',
#   'AkhilKumarSaho8',
#   2,
#   1,
#   ''],
#  [datetime.datetime(2023, 6, 13, 4, 52, 38, tzinfo=datetime.timezone.utc),
#   1668481478823497728,
#   'People who are saying k Abdullah shah ghazi ki wajah se (نعوذ باللہ) cyclone chala giya hai let me tell you a story : kedarnath is a temple in utarkhand India dedicated to deity shiva. In 2010 a massive flood appeared there causing massive destruction all buildings collapsed',
#   'ussBrouss',
#   1,
#   0,
#   ''],
#  ...]

# %%
# tweet_df = pd.DataFrame(tweet_data, columns=['date', 'id', 'content', 'username', 'like', 'retweet'])
tweet_flood_df = pd.DataFrame(tweet_data_with_user_location, columns=['date', 'id','content','username', 'like','retweet', 'user_location'])

# %%
tweet_flood_df['date'] = pd.to_datetime(tweet_flood_df['date']).dt.date

# %%
tweet_flood_df.to_excel("twitter_with_user_location.xlsx",index= False)

# %%
df= pd.read_excel("twitter_with_user_location.xlsx")
df.head()
# Out:
#         date                   id  \
# 0 2023-06-28  1673917823100521984
# 1 2023-06-28  1673917116733349888
# 2 2023-06-28  1673917069488979968
# 3 2023-06-28  1673911653652626944
# 4 2023-06-28  1673911602402450944
#
#                                              content         username  like  \
# 0  One main cause of these floods is infrastructu...  Ashwini96988554     0
# 1  @TimothyGouldso1 @JustinTrudeau world wide we ...    londonwriters     0
# 2  Did y'all know that since 2014, India as becom...  Ashwini96988554     1
# 3  Assam Braces for Eid Amidst Devastating Floods...  newsnortheastin     0
# 4  Heavy rains hit the city of #Ahmedabad, #India...      cgtnamerica     3
#
#    retweet                                  user_location
# 0        0                                          India
# 1        0  Vancouver / Toronto / London, Montreal , Roma
# 2        0                                          India
# 3        0                                            NaN
# 4        1                                 Washington, DC

# %%
df.shape
# Out:
# (2334, 7)
