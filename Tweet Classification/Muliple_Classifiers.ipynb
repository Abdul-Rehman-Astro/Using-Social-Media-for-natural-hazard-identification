# %%
import numpy as np
import pandas as pd
# Out:
# Running cells with '/bin/python3.12' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/bin/python3.12 -m pip install ipykernel -U --user --force-reinstall'

# %%
df= pd.read_excel("/media/krishna/88356b6e-eda9-4612-9c56-c44911a1b8ae/NLP Project/Tweet Classification/twitter.xlsx",'Sheet2')
train_df = df.head(600)
train_df.head(10)
# Out:
#                                              content LABEL
# 0  #AssamFloods update: There is no respite from ...     1
# 1  At least 496 thousand people were in the flood...     1
# 2   @NagpurKaRajini Jai Agniveers are being train...     1
# 3  FLOOD SITUATION IN ASSAM WORSENS.0\n #Titanic ...     1
# 4  #Assam State Disaster Management Authority (AS...     1
# 5  The #flood situation in #Assam showed no signs...     1
# 6  Impressive spectacle of #Sylhet Flood Plains (...     1
# 7  Flood situation in Assam grim with around five...     1
# 8  Floods and Landslides Kill at Least 70 in Indi...     1
# 9  @KenRoth There is flood of such articles in th...     0

# %% [markdown]
# ## Preprocess

# %%
train_df['LABEL'].isnull().sum()
# Out:
# 5

# %%
train_df['LABEL'].fillna(value='1/0', inplace=True)
# Out:
# /tmp/ipykernel_10796/2380557590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['LABEL'].fillna(value='1/0', inplace=True)

# %%
train_df.head(30)
# Out:
#                                               content LABEL
# 0   #AssamFloods update: There is no respite from ...     1
# 1   At least 496 thousand people were in the flood...     1
# 2    @NagpurKaRajini Jai Agniveers are being train...     1
# 3   FLOOD SITUATION IN ASSAM WORSENS.0\n #Titanic ...     1
# 4   #Assam State Disaster Management Authority (AS...     1
# 5   The #flood situation in #Assam showed no signs...     1
# 6   Impressive spectacle of #Sylhet Flood Plains (...     1
# 7   Flood situation in Assam grim with around five...     1
# 8   Floods and Landslides Kill at Least 70 in Indi...     1
# 9   @KenRoth There is flood of such articles in th...     0
# 10  The flood situation in Assam deteriorated dras...     1
# 11  India – Over 100,000 Hit by Floods in 20 Distr...     1
# 12  @SantoshMoh22786 @TheSincereDude Oh, got it. M...   1/0
# 13  Water here water there flood in Assam India 🌿 ...     1
# 14  Dear @AmitShah after visiting Gujarat please v...     1
# ...

# %% [markdown]
# #### maping of labels onto tag

# %%
#Add the new column which gives a unique number to each of these labels 
train_df['label_tag'] = df['LABEL'].map({ 0 :'Non Flooded',1: "Flooded" , 2 : "Cannot Say"})
# Out:
# /tmp/ipykernel_10796/3210088018.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df['label_tag'] = df['LABEL'].map({ 0 :'Non Flooded',1: "Flooded" , 2 : "Cannot Say"})

# %%
train_df.head(30)
# Out:
#                                               content LABEL    label_tag
# 0   #AssamFloods update: There is no respite from ...     1      Flooded
# 1   At least 496 thousand people were in the flood...     1      Flooded
# 2    @NagpurKaRajini Jai Agniveers are being train...     1      Flooded
# 3   FLOOD SITUATION IN ASSAM WORSENS.0\n #Titanic ...     1      Flooded
# 4   #Assam State Disaster Management Authority (AS...     1      Flooded
# 5   The #flood situation in #Assam showed no signs...     1      Flooded
# 6   Impressive spectacle of #Sylhet Flood Plains (...     1      Flooded
# 7   Flood situation in Assam grim with around five...     1      Flooded
# 8   Floods and Landslides Kill at Least 70 in Indi...     1      Flooded
# 9   @KenRoth There is flood of such articles in th...     0  Non Flooded
# 10  The flood situation in Assam deteriorated dras...     1      Flooded
# 11  India – Over 100,000 Hit by Floods in 20 Distr...     1      Flooded
# ...

# %% [markdown]
# # Models download

# %% [markdown]
# ### Get spacy word vectors and store them in a pandas dataframe

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_10796/3289892424.py in <module>
# ----> 1 import spacy
#       2 nlp = spacy.load("en_core_web_sm")
#
# ModuleNotFoundError: No module named 'spacy'

# %%
## I am unable to use web_large model

import spacy
nlp = spacy.load("en_core_web_lg")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_30959/2825980420.py in <module>
#       2
#       3 import spacy
# ----> 4 nlp = spacy.load("en_core_web_lg")
#
# ~/anaconda3/lib/python3.9/site-packages/spacy/__init__.py in load(name, vocab, disable, exclude, config)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      53     )
#
# ~/anaconda3/lib/python3.9/site-packages/spacy/util.py in load_model(name, vocab, disable, exclude, config)
#     425     if name in OLD_MODEL_SHORTCUTS:
#     426         raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 427     raise IOError(Errors.E050.format(name=name))
#     428
#     429
#
# ...

# %%
type(train_df)
# Out:
# pandas.core.frame.DataFrame

# %%
new_vector =[]


for i in range(600):
# Out:
#   File "/tmp/ipykernel_142890/1502362968.py", line 2
#
#     ^
# IndentationError: expected an indented block

# %%
#This will take some time(nearly 15 minutes)
train_df['vector'] = train_df['content'].apply(lambda content: nlp(content).vector)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_142890/1951075714.py in <module>
#       1 #This will take some time(nearly 15 minutes)
# ----> 2 train_df['vector'] = train_df['content'].apply(lambda content: nlp(content).vector)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    train_df.vector.values,
    train_df.label_num,
    test_size=0.2,
    random_state=2022
)
